# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from icecream import ic
from sklearn.preprocessing import LabelEncoder
import time
from itertools import product
from icecream import ic


plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

sales_train = pd.read_csv('./data/sales_train.csv')
test = pd.read_csv('./data/test.csv')   # (214200, 3)

# 计算每个商品每个月的销售量，假如某个商品在某个月没有数据，则填充0（即这个月的销售量为0）
sales_by_item_id = sales_train.pivot_table(index=['item_id'], values=['item_cnt_day'], columns='date_block_num', aggfunc=np.sum, fill_value=0).reset_index()
sales_by_item_id.columns = sales_by_item_id.columns.droplevel().map(str)   # 去掉第一层索引
sales_by_item_id.columns.values[0] = 'item_id'
sales_by_item_id = sales_by_item_id.rename_axis(None, axis=1)

# 获取最近6个月销售量为0的数据
six_zero = sales_by_item_id[(sales_by_item_id['28'] == 0) & (sales_by_item_id['29'] == 0) & (sales_by_item_id['30'] == 0) & (sales_by_item_id['31'] == 0) & (sales_by_item_id['32'] == 0) & (sales_by_item_id['33'] == 0)]
six_zero_item_id = list(six_zero['item_id'].values)   # item_id列表
# test.loc[test.item_id.isin(six_zero_item_id), 'item_cnt_month'] = 0  # 将test数据中（最近六个月销量为0）的数据月销量设为0，有7812个

# 计算每个商店每个月的销量
sales_by_shop_id = sales_train.pivot_table(index=['shop_id'], values=['item_cnt_day'], aggfunc=np.sum, fill_value=0, columns='date_block_num').reset_index()
sales_by_shop_id.columns = sales_by_shop_id.columns.droplevel().map(str)    # 将两层column转化为一层column,保留下层column
sales_by_shop_id.columns.values[0] = 'shop_id'
sales_by_shop_id = sales_by_shop_id.rename_axis(None, axis=1)   # 将列方向的轴重命名为none

# zero = sales_train[sales_train.date_block_num==0]
# ic(zero.shop_id.unique(), len(zero.item_id.unique()), len(zero.shop_id.unique()), len(zero.shop_id.unique()) * len(zero.item_id.unique()))
# ic(sales_train.shop_id.unique(), len(sales_train.item_id.unique()), len(sales_train.shop_id.unique()), len(sales_train.shop_id.unique()) * len(sales_train.item_id.unique()))

"""组合date_block_num,shop_id,item_id(部分) 总量：10913850"""
matrix = []
cols = ['date_block_num','shop_id','item_id']
for i in range(34):
    sales = sales_train[sales_train.date_block_num==i]
    matrix.append(np.array(list(product([i], sales.shop_id.unique(), sales.item_id.unique())), dtype='int16'))
matrix = pd.DataFrame(np.vstack(matrix), columns=cols)
matrix['date_block_num'] = matrix['date_block_num'].astype(np.int8)
matrix['shop_id'] = matrix['shop_id'].astype(np.int8)
matrix.sort_values(cols, inplace=True)  # 排序
sales_train['revenue'] = sales_train['item_price'] * sales_train['item_cnt_day']    # 某一天的销售额

# 分组
groupby = sales_train.groupby(['shop_id','item_id','date_block_num']).agg({'item_cnt_day': 'sum'}).reset_index()
groupby = groupby.rename(columns={'item_cnt_day': 'item_cnt_month'})
matrix = matrix.merge(groupby, on=['date_block_num','shop_id','item_id'], how='left')
matrix['item_cnt_month'] = matrix['item_cnt_month'].fillna(0).clip(0, 20)
matrix['item_cnt_month'] = matrix['item_cnt_month'].astype(np.float16)

# test数据
test['date_block_num'] = 34
test['date_block_num'] = test['date_block_num'].astype(np.int8)
test['shop_id'] = test['shop_id'].astype(np.int8)
test['item_id'] = test['item_id'].astype(np.int16)

# 合并matrix,test
matrix = pd.concat([matrix, test[cols]], ignore_index=True, axis=0)
matrix['item_cnt_month'].fillna(0, inplace=True)

# 商品信息
items = pd.read_csv('./data/items.csv')
items = items[['item_id', 'item_category_id']]
matrix = pd.merge(left=matrix, right=items, on='item_id', how='left')  # 合并

# 商品类别
le = LabelEncoder()
categories = pd.read_csv('./data/item_categories.csv')
categories['split'] = categories['item_category_name'].str.split('-')
categories['type'] = categories['split'].map(lambda x:x[0].strip())
categories['subtype'] = categories['split'].map(lambda x:x[1].strip() if len(x)>1 else x[0].strip())
categories = categories[['item_category_id','type','subtype']]
categories['cat_type_code'] = le.fit_transform(categories['type'])
categories['cat_subtype_code'] = le.fit_transform(categories['subtype'])
matrix = pd.merge(left=matrix, right=categories[['item_category_id','cat_type_code','cat_subtype_code']], on='item_category_id', how='left')    # 合并

# 商店信息
shops = pd.read_csv('./data/shops.csv')
shops['split']=shops.shop_name.str.split(' ')
shops['shop_city'] = shops['split'].map(lambda x:x[0])
shops['shop_city_code'] = le.fit_transform(shops['shop_city'])

def st(name):
    if 'ТЦ' in name or 'ТРЦ' in name:
        shopt = 'ТЦ'
    elif 'ТК' in name:
        shopt = 'ТК'
    elif 'ТРК' in name:
        shopt = 'ТРК'
    elif 'МТРЦ' in name:
        shopt = 'МТРЦ'
    else:
        shopt = 'UNKNOWN'
    return shopt
shops['shop_type'] = shops['shop_name'].apply(st)

shops.loc[shops.shop_id == 21, 'shop_type'] = 'МТРЦ'   # 修正
shops['shop_type_code'] = le.fit_transform(shops['shop_type'])
matrix = pd.merge(left=matrix, right=shops[['shop_id','shop_city_code','shop_type_code']], on='shop_id', how='left')    # 合并
matrix['item_category_id'] = matrix['item_category_id'].astype(np.int8)
matrix['cat_type_code'] = matrix['cat_type_code'].astype(np.int8)
matrix['cat_subtype_code'] = matrix['cat_subtype_code'].astype(np.int8)
matrix['shop_city_code'] = matrix['shop_city_code'].astype(np.int8)
matrix['shop_type_code'] = matrix['shop_type_code'].astype(np.int8)


"""历史信息"""

def lag_features(df, lags, col):
    tmp = df[['date_block_num','shop_id','item_id',col]]
    for i in lags:
        shifted = tmp.copy()
        shifted.columns = ['date_block_num','shop_id','item_id',col+'_lag_'+str(i)]
        shifted['date_block_num'] = shifted['date_block_num'] + i
        df = pd.merge(left=df, right=shifted, on=['date_block_num','shop_id','item_id'], how='left')
    return df

matrix = lag_features(matrix, [1,2,3,6,12], 'item_cnt_month')

# 月销量（所有商品）
group = matrix.groupby('date_block_num').agg({'item_cnt_month': 'mean'}).reset_index()
group.columns = ['date_block_num', 'date_avg_item_cnt']
matrix = pd.merge(left=matrix, right=group, on='date_block_num', how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_avg_item_cnt')
matrix.drop('date_avg_item_cnt', axis=1, inplace=True)

# 月销量（每一件商品）
group = matrix.groupby(['date_block_num', 'item_id']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_item_avg_item_cnt' ]
group.reset_index(inplace=True)
matrix = pd.merge(left=matrix, right=group, on=['date_block_num','item_id'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_item_avg_item_cnt')
matrix.drop('date_item_avg_item_cnt', axis=1, inplace=True)

# 月销量（每个商店 ）
group = matrix.groupby(['date_block_num','shop_id']).agg({'item_cnt_month': 'mean'})
group.columns = ['date_shop_avg_item_cnt']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on=['date_block_num','shop_id'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_shop_avg_item_cnt')
matrix.drop('date_shop_avg_item_cnt', axis=1, inplace=True)

# 月销量（每个类别）
group = matrix.groupby(['date_block_num','item_category_id']).agg({'item_cnt_month': 'mean'})
group.columns = ['date_cat_avg_item_cnt']
group = group.reset_index()
matrix=pd.merge(left=matrix, right=group, on=['date_block_num','item_category_id'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_cat_avg_item_cnt')
matrix.drop('date_cat_avg_item_cnt', axis=1, inplace=True)

# 月销量（商品类别-商店）
group = matrix.groupby(['date_block_num','item_category_id','shop_id']).agg({'item_cnt_month': 'mean'})
group.columns = ['date_cat_shop_avg_item_cnt']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on=['date_block_num','item_category_id','shop_id'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_cat_shop_avg_item_cnt')
matrix.drop('date_cat_shop_avg_item_cnt', axis=1, inplace=True)

# 月销量（商品大类）
group = matrix.groupby(['date_block_num','cat_type_code']).agg({'item_cnt_month': 'mean'})
group.columns = ['date_type_avg_item_cnt']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on=['date_block_num','cat_type_code'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_type_avg_item_cnt')
matrix.drop('date_type_avg_item_cnt', axis=1, inplace=True)

# 月销量（商品-商品大类） ++++++++++++ 和 月销量（商品）是重复的，因为每一个商品，类别是确定的，大类也是确定的
group = matrix.groupby(['date_block_num', 'item_id', 'cat_type_code']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_item_type_avg_item_cnt']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on=['date_block_num', 'item_id', 'cat_type_code'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_item_type_avg_item_cnt')
matrix.drop('date_item_type_avg_item_cnt', axis=1, inplace=True)

# 月销量（商店城市）
group = matrix.groupby(['date_block_num','shop_city_code']).agg({'item_cnt_month': 'mean'})
group.columns = ['date_city_avg_item_cnt']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on=['date_block_num','shop_city_code'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_city_avg_item_cnt')
matrix.drop('date_city_avg_item_cnt', axis=1, inplace=True)

# 月销量（商品-商店城市）
group = matrix.groupby(['date_block_num', 'item_id', 'shop_city_code']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_item_city_avg_item_cnt']
group = group.reset_index()
matrix=pd.merge(left=matrix, right=group, on=['date_block_num', 'item_id', 'shop_city_code'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_item_city_avg_item_cnt')
matrix.drop('date_item_city_avg_item_cnt', axis=1, inplace=True)

# 趋势特征
group = sales_train.groupby('item_id').agg({'item_price': 'mean'})
group.columns = ['item_avg_item_price']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on='item_id', how='left')

group = sales_train.groupby(['date_block_num','item_id']).agg({'item_price': 'mean'})
group.columns = ['date_item_avg_item_price']
group = group.reset_index()
matrix=pd.merge(left=matrix, right=group, on=['date_block_num','item_id'], how='left')

matrix['item_avg_item_price'] = matrix['item_avg_item_price'].astype(np.float16)
matrix['date_item_avg_item_price'] = matrix['date_item_avg_item_price'].astype(np.float16)

# 计算matrix中商品的历史价格
lags = [1,2,3,4,5,6,12]
matrix = lag_features(matrix, lags, 'date_item_avg_item_price')
for i in lags:
    matrix['delta_price_lag_'+str(i)] = (matrix['date_item_avg_item_price_lag_' + str(i)] - matrix['item_avg_item_price']) / matrix['item_avg_item_price']

def select_trend(row):
    for i in lags:
        if pd.notnull(row['delta_price_lag_'+str(i)]):  # 如果不是NaN
            return row['delta_price_lag_'+str(i)]
    return 0   #  如果delta_price_lag_都为空，那么将趋势设为0，0代表没有趋势

matrix['delta_price_lag'] = matrix.apply(select_trend, axis=1)
matrix['delta_price_lag'] = matrix['delta_price_lag'].astype(np.float16)

features_to_drop = ['item_avg_item_price','date_item_avg_item_price']
for i in lags:
    features_to_drop += ['date_item_avg_item_price_lag_'+str(i)]
    features_to_drop += ['delta_price_lag_'+str(i)]
matrix.drop(features_to_drop, axis=1, inplace=True)

# 每个月的天数
matrix['month'] = matrix['date_block_num'] % 12
days = pd.Series([31,28,31,30,31,30,31,31,30,31,30,31])
matrix['days'] = matrix['month'].map(days)
matrix['days'] = matrix['days'].astype(np.int8)

# 开始销量
matrix['item_shop_first_sale'] = matrix['date_block_num'] - matrix.groupby(['item_id','shop_id'])['date_block_num'].transform('min')
matrix['item_first_sale'] = matrix['date_block_num'] - matrix.groupby('item_id')['date_block_num'].transform('min')

# 因为有12个月的延迟特征（1，2，3，6，12）（1，2，3，4，5，6，12），所以需要删除前12月的数据
matrix = matrix[matrix['date_block_num'] > 11]

# 找到有NaN值的列，然后把那些列中的NaN值填充0
columns = matrix.columns
column_null = []
for i in columns:
    if len(matrix[matrix[i].isnull()]) > 0:
        column_null.append(i)

for i in column_null:
    matrix[i].fillna(0, inplace=True)

# %%
sales_train
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day  revenue
# 0                 1.0   999.00
# 1                 1.0   899.00
# 2                -1.0  -899.00
# 3                 1.0  1709.05
# 4                 1.0  1099.00
# ...               ...      ...
# 2935844           1.0   299.00
# 2935845           1.0   299.00
# 2935846           1.0   349.00
# 2935847           1.0   299.00
# 2935848           1.0   299.00
#
# [2935849 rows x 7 columns]

# %%
matrix
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  item_category_id  \
# 4488756               12        2       27             0.0                19
# 4488757               12        2       30             0.0                40
# 4488758               12        2       31             0.0                37
# 4488759               12        2       32             1.0                40
# 4488760               12        2       33             1.0                37
# ...                  ...      ...      ...             ...               ...
# 11128045              34       45    18454             0.0                55
# 11128046              34       45    16188             0.0                64
# 11128047              34       45    15757             0.0                55
# 11128048              34       45    19648             0.0                40
# 11128049              34       45      969             0.0                37
#
#           cat_type_code  cat_subtype_code  shop_city_code  shop_type_code  \
# 4488756               5                10               1               4
# 4488757              11                 4               1               4
# 4488758              11                 1               1               4
# 4488759              11                 4               1               4
# 4488760              11                 1               1               4
# ...                 ...               ...             ...             ...
# 11128045             13                 2              21               4
# 11128046             14                42              21               4
# 11128047             13                 2              21               4
# 11128048             11                 4              21               4
# 11128049             11                 1              21               4
#
#           item_cnt_month_lag_1  ...  date_item_city_avg_item_cnt_lag_1  \
# 4488756                    0.0  ...                                0.0
# 4488757                    0.0  ...                                0.0
# 4488758                    0.0  ...                                0.0
# 4488759                    0.0  ...                                0.0
# 4488760                    1.0  ...                                1.0
# ...                        ...  ...                                ...
# 11128045                   1.0  ...                                0.5
# 11128046                   0.0  ...                                0.0
# 11128047                   0.0  ...                                0.0
# 11128048                   0.0  ...                                0.0
# 11128049                   0.0  ...                                0.5
#
#           date_item_city_avg_item_cnt_lag_2  \
# 4488756                                 0.0
# 4488757                                 0.0
# 4488758                                 0.0
# 4488759                                 0.0
# 4488760                                 2.0
# ...                                     ...
# 11128045                                0.0
# 11128046                                0.0
# 11128047                                0.5
# 11128048                                0.0
# 11128049                                0.0
#
#           date_item_city_avg_item_cnt_lag_3  \
# 4488756                                 0.0
# 4488757                                 0.0
# 4488758                                 0.0
# 4488759                                 0.0
# 4488760                                 0.0
# ...                                     ...
# 11128045                                0.0
# 11128046                                0.0
# 11128047                                0.0
# 11128048                                0.0
# 11128049                                0.0
#
#           date_item_city_avg_item_cnt_lag_6  \
# 4488756                                 0.0
# 4488757                                 0.0
# 4488758                                 0.0
# 4488759                                 0.0
# 4488760                                 0.0
# ...                                     ...
# 11128045                                0.0
# 11128046                                0.0
# 11128047                                0.0
# 11128048                                0.0
# 11128049                                0.0
#
#           date_item_city_avg_item_cnt_lag_12  delta_price_lag  month  days  \
# 4488756                                  1.0        -0.282715      0    31
# 4488757                                  0.0        -0.483398      0    31
# 4488758                                  0.0        -0.137451      0    31
# 4488759                                  0.0        -0.407227      0    31
# 4488760                                  1.0        -0.225464      0    31
# ...                                      ...              ...    ...   ...
# 11128045                                 0.0        -0.475098     10    30
# 11128046                                 0.0         0.081116     10    30
# 11128047                                 0.0         0.155884     10    30
# 11128048                                 0.0        -0.091736     10    30
# 11128049                                 0.0        -0.605957     10    30
#
#           item_shop_first_sale  item_first_sale
# 4488756                     12               12
# 4488757                     11               11
# 4488758                     11               11
# 4488759                     12               12
# 4488760                     12               12
# ...                        ...              ...
# 11128045                    11               11
# 11128046                     2                2
# 11128047                    34               34
# 11128048                    11               11
# 11128049                    17               17
#
# [6639294 rows x 64 columns]

# %%
matrix1 = matrix.copy()
matrix2 = matrix.copy()

# %%
2**8
# Out:
# 256

# %% [markdown]
# #  特征选择

# %%
from sklearn.feature_selection import SelectKBest

# %%
trainData = matrix[matrix['date_block_num'] < 33]
label_train = trainData['item_cnt_month']
X_train = trainData.drop('item_cnt_month', axis=1)

validData = matrix[matrix['date_block_num'] == 33]
label_valid = validData['item_cnt_month']
X_valid = validData.drop('item_cnt_month', axis=1)

import lightgbm as lgb
train_data = lgb.Dataset(data=X_train, label=label_train)
valid_data = lgb.Dataset(data=X_valid, label=label_valid)
params = {
    'objective': 'regression',  # 回归
    'metric': 'rmse',   # 回归问题选择rmse
    'n_estimators': 4000,
    'max_depth': 8,
    'num_leaves': 220,   # 每个弱学习器拥有的叶子的数量
    'learning_rate': 0.005,
    'bagging_fraction': 0.9,    # 每次训练“弱学习器”用的数据比例（应该也是随机的），用于加快训练速度和减小过拟合
    'feature_fraction': 0.3,   # 每次迭代过程中，随机选择30%的特征建树（弱学习器）
    'bagging_seed': 0,
    'early_stop_rounds': 50
}
lgb_model = lgb.train(params, train_data, valid_sets=[train_data, valid_data])
# Out:
# d:\program files\python37\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Unknown parameter: early_stop_rounds
# [LightGBM] [Warning] Unknown parameter: early_stop_rounds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.208615 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10805
# [LightGBM] [Info] Number of data points in the train set: 6186922, number of used features: 63
# [LightGBM] [Warning] Unknown parameter: early_stop_rounds
# [LightGBM] [Info] Start training from score 0.288852
# [1]	training's rmse: 1.18562	valid_1's rmse: 1.13456
# [2]	training's rmse: 1.18312	valid_1's rmse: 1.13269
# [3]	training's rmse: 1.18118	valid_1's rmse: 1.13108
# [4]	training's rmse: 1.17929	valid_1's rmse: 1.12975
# [5]	training's rmse: 1.1769	valid_1's rmse: 1.12806
# [6]	training's rmse: 1.17508	valid_1's rmse: 1.12673
# [7]	training's rmse: 1.17298	valid_1's rmse: 1.12502
# [8]	training's rmse: 1.1706	valid_1's rmse: 1.12335
# [9]	training's rmse: 1.16837	valid_1's rmse: 1.12181
# [10]	training's rmse: 1.16619	valid_1's rmse: 1.12024
# [11]	training's rmse: 1.16385	valid_1's rmse: 1.11858
# [12]	training's rmse: 1.16162	valid_1's rmse: 1.11702
# [13]	training's rmse: 1.15941	valid_1's rmse: 1.11547
# [14]	training's rmse: 1.15741	valid_1's rmse: 1.11412
# [15]	training's rmse: 1.15538	valid_1's rmse: 1.11267
# [16]	training's rmse: 1.15319	valid_1's rmse: 1.11109
# [17]	training's rmse: 1.15115	valid_1's rmse: 1.10971
# [18]	training's rmse: 1.14905	valid_1's rmse: 1.10831
# [19]	training's rmse: 1.14697	valid_1's rmse: 1.10687
# [20]	training's rmse: 1.14525	valid_1's rmse: 1.10561
# [21]	training's rmse: 1.14315	valid_1's rmse: 1.10416
# [22]	training's rmse: 1.14111	valid_1's rmse: 1.10259
# [23]	training's rmse: 1.1393	valid_1's rmse: 1.10116
# [24]	training's rmse: 1.13729	valid_1's rmse: 1.0998
# [25]	training's rmse: 1.13517	valid_1's rmse: 1.09825
# [26]	training's rmse: 1.1331	valid_1's rmse: 1.09671
# [27]	training's rmse: 1.13146	valid_1's rmse: 1.09548
# [28]	training's rmse: 1.12947	valid_1's rmse: 1.09407
# [29]	training's rmse: 1.12754	valid_1's rmse: 1.09276
# [30]	training's rmse: 1.12556	valid_1's rmse: 1.09137
# [31]	training's rmse: 1.12343	valid_1's rmse: 1.08978
# [32]	training's rmse: 1.12163	valid_1's rmse: 1.08854
# [33]	training's rmse: 1.12025	valid_1's rmse: 1.08752
# [34]	training's rmse: 1.11824	valid_1's rmse: 1.08606
# [35]	training's rmse: 1.11641	valid_1's rmse: 1.08478
# [36]	training's rmse: 1.11519	valid_1's rmse: 1.08392
# [37]	training's rmse: 1.11351	valid_1's rmse: 1.08261
# [38]	training's rmse: 1.11213	valid_1's rmse: 1.08159
# [39]	training's rmse: 1.11032	valid_1's rmse: 1.0804
# [40]	training's rmse: 1.10858	valid_1's rmse: 1.07919
# [41]	training's rmse: 1.10664	valid_1's rmse: 1.07788
# [42]	training's rmse: 1.10496	valid_1's rmse: 1.07678
# [43]	training's rmse: 1.10318	valid_1's rmse: 1.0756
# [44]	training's rmse: 1.1016	valid_1's rmse: 1.0745
# [45]	training's rmse: 1.10023	valid_1's rmse: 1.07355
# [46]	training's rmse: 1.09836	valid_1's rmse: 1.07224
# [47]	training's rmse: 1.0965	valid_1's rmse: 1.07096
# [48]	training's rmse: 1.09453	valid_1's rmse: 1.06944
# [49]	training's rmse: 1.09283	valid_1's rmse: 1.06834
# [50]	training's rmse: 1.09104	valid_1's rmse: 1.0671
# [51]	training's rmse: 1.0894	valid_1's rmse: 1.06597
# [52]	training's rmse: 1.08774	valid_1's rmse: 1.06482
# [53]	training's rmse: 1.08602	valid_1's rmse: 1.06369
# [54]	training's rmse: 1.08429	valid_1's rmse: 1.06243
# [55]	training's rmse: 1.08263	valid_1's rmse: 1.06116
# [56]	training's rmse: 1.08117	valid_1's rmse: 1.05995
# [57]	training's rmse: 1.07947	valid_1's rmse: 1.05867
# [58]	training's rmse: 1.07784	valid_1's rmse: 1.0576
# [59]	training's rmse: 1.07601	valid_1's rmse: 1.05627
# [60]	training's rmse: 1.07411	valid_1's rmse: 1.05488
# [61]	training's rmse: 1.07278	valid_1's rmse: 1.05389
# [62]	training's rmse: 1.07125	valid_1's rmse: 1.05289
# [63]	training's rmse: 1.06954	valid_1's rmse: 1.05174
# [64]	training's rmse: 1.06826	valid_1's rmse: 1.05084
# [65]	training's rmse: 1.06703	valid_1's rmse: 1.05002
# [66]	training's rmse: 1.06552	valid_1's rmse: 1.04897
# [67]	training's rmse: 1.06396	valid_1's rmse: 1.04791
# [68]	training's rmse: 1.06285	valid_1's rmse: 1.04715
# [69]	training's rmse: 1.06116	valid_1's rmse: 1.04601
# [70]	training's rmse: 1.05958	valid_1's rmse: 1.04497
# [71]	training's rmse: 1.05798	valid_1's rmse: 1.04389
# [72]	training's rmse: 1.05644	valid_1's rmse: 1.04277
# [73]	training's rmse: 1.05499	valid_1's rmse: 1.04178
# [74]	training's rmse: 1.05346	valid_1's rmse: 1.04075
# [75]	training's rmse: 1.05183	valid_1's rmse: 1.03962
# [76]	training's rmse: 1.05036	valid_1's rmse: 1.03858
# [77]	training's rmse: 1.04884	valid_1's rmse: 1.03754
# [78]	training's rmse: 1.0474	valid_1's rmse: 1.03661
# [79]	training's rmse: 1.0461	valid_1's rmse: 1.03557
# [80]	training's rmse: 1.04506	valid_1's rmse: 1.03489
# [81]	training's rmse: 1.04364	valid_1's rmse: 1.03395
# [82]	training's rmse: 1.04228	valid_1's rmse: 1.03301
# [83]	training's rmse: 1.04086	valid_1's rmse: 1.03202
# [84]	training's rmse: 1.03964	valid_1's rmse: 1.03109
# [85]	training's rmse: 1.03823	valid_1's rmse: 1.03014
# [86]	training's rmse: 1.03681	valid_1's rmse: 1.02917
# [87]	training's rmse: 1.03582	valid_1's rmse: 1.02853
# [88]	training's rmse: 1.03431	valid_1's rmse: 1.02741
# [89]	training's rmse: 1.03291	valid_1's rmse: 1.0265
# [90]	training's rmse: 1.03192	valid_1's rmse: 1.02585
# [91]	training's rmse: 1.03047	valid_1's rmse: 1.02486
# [92]	training's rmse: 1.02908	valid_1's rmse: 1.02387
# [93]	training's rmse: 1.0278	valid_1's rmse: 1.02289
# [94]	training's rmse: 1.02666	valid_1's rmse: 1.02221
# [95]	training's rmse: 1.02531	valid_1's rmse: 1.0211
# [96]	training's rmse: 1.02388	valid_1's rmse: 1.02006
# [97]	training's rmse: 1.02272	valid_1's rmse: 1.01933
# [98]	training's rmse: 1.02125	valid_1's rmse: 1.01826
# [99]	training's rmse: 1.02046	valid_1's rmse: 1.01753
# [100]	training's rmse: 1.01919	valid_1's rmse: 1.0167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	training's rmse: 1.01796	valid_1's rmse: 1.01588
# [102]	training's rmse: 1.01667	valid_1's rmse: 1.01502
# [103]	training's rmse: 1.01547	valid_1's rmse: 1.01425
# [104]	training's rmse: 1.0142	valid_1's rmse: 1.0134
# [105]	training's rmse: 1.01293	valid_1's rmse: 1.0126
# [106]	training's rmse: 1.01155	valid_1's rmse: 1.0117
# [107]	training's rmse: 1.01041	valid_1's rmse: 1.01094
# [108]	training's rmse: 1.00927	valid_1's rmse: 1.01025
# [109]	training's rmse: 1.0084	valid_1's rmse: 1.00968
# [110]	training's rmse: 1.00712	valid_1's rmse: 1.00877
# [111]	training's rmse: 1.00597	valid_1's rmse: 1.00802
# [112]	training's rmse: 1.00472	valid_1's rmse: 1.00711
# [113]	training's rmse: 1.00356	valid_1's rmse: 1.00638
# [114]	training's rmse: 1.00276	valid_1's rmse: 1.00577
# [115]	training's rmse: 1.00154	valid_1's rmse: 1.00496
# [116]	training's rmse: 1.00038	valid_1's rmse: 1.00413
# [117]	training's rmse: 0.99927	valid_1's rmse: 1.00344
# [118]	training's rmse: 0.997935	valid_1's rmse: 1.00252
# [119]	training's rmse: 0.997032	valid_1's rmse: 1.00185
# [120]	training's rmse: 0.995964	valid_1's rmse: 1.00115
# [121]	training's rmse: 0.994987	valid_1's rmse: 1.00037
# [122]	training's rmse: 0.993745	valid_1's rmse: 0.999511
# [123]	training's rmse: 0.99267	valid_1's rmse: 0.998799
# [124]	training's rmse: 0.991566	valid_1's rmse: 0.998099
# [125]	training's rmse: 0.990489	valid_1's rmse: 0.997423
# [126]	training's rmse: 0.989339	valid_1's rmse: 0.996654
# [127]	training's rmse: 0.988194	valid_1's rmse: 0.995889
# [128]	training's rmse: 0.987119	valid_1's rmse: 0.995121
# [129]	training's rmse: 0.986265	valid_1's rmse: 0.99454
# [130]	training's rmse: 0.985492	valid_1's rmse: 0.993884
# [131]	training's rmse: 0.984263	valid_1's rmse: 0.993063
# [132]	training's rmse: 0.983268	valid_1's rmse: 0.99243
# [133]	training's rmse: 0.98223	valid_1's rmse: 0.991762
# [134]	training's rmse: 0.98115	valid_1's rmse: 0.990965
# [135]	training's rmse: 0.980193	valid_1's rmse: 0.990387
# [136]	training's rmse: 0.979207	valid_1's rmse: 0.989772
# [137]	training's rmse: 0.978197	valid_1's rmse: 0.989177
# [138]	training's rmse: 0.977092	valid_1's rmse: 0.988398
# [139]	training's rmse: 0.976076	valid_1's rmse: 0.987786
# [140]	training's rmse: 0.975315	valid_1's rmse: 0.987297
# [141]	training's rmse: 0.974331	valid_1's rmse: 0.986654
# [142]	training's rmse: 0.973621	valid_1's rmse: 0.986152
# [143]	training's rmse: 0.972519	valid_1's rmse: 0.985423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	training's rmse: 0.971613	valid_1's rmse: 0.984871
# [145]	training's rmse: 0.970568	valid_1's rmse: 0.984128
# [146]	training's rmse: 0.969604	valid_1's rmse: 0.983499
# [147]	training's rmse: 0.968692	valid_1's rmse: 0.982924
# [148]	training's rmse: 0.968008	valid_1's rmse: 0.982462
# [149]	training's rmse: 0.967137	valid_1's rmse: 0.981915
# [150]	training's rmse: 0.966207	valid_1's rmse: 0.981332
# [151]	training's rmse: 0.965521	valid_1's rmse: 0.980891
# [152]	training's rmse: 0.964602	valid_1's rmse: 0.980336
# [153]	training's rmse: 0.963772	valid_1's rmse: 0.97983
# [154]	training's rmse: 0.963281	valid_1's rmse: 0.979519
# [155]	training's rmse: 0.962389	valid_1's rmse: 0.978917
# [156]	training's rmse: 0.961521	valid_1's rmse: 0.978417
# [157]	training's rmse: 0.960934	valid_1's rmse: 0.97802
# [158]	training's rmse: 0.960275	valid_1's rmse: 0.977556
# [159]	training's rmse: 0.959403	valid_1's rmse: 0.977027
# [160]	training's rmse: 0.958493	valid_1's rmse: 0.976415
# [161]	training's rmse: 0.95766	valid_1's rmse: 0.975951
# [162]	training's rmse: 0.956823	valid_1's rmse: 0.975314
# [163]	training's rmse: 0.955897	valid_1's rmse: 0.974751
# [164]	training's rmse: 0.955118	valid_1's rmse: 0.974295
# [165]	training's rmse: 0.954291	valid_1's rmse: 0.973867
# [166]	training's rmse: 0.953487	valid_1's rmse: 0.973413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	training's rmse: 0.952651	valid_1's rmse: 0.972938
# [168]	training's rmse: 0.951791	valid_1's rmse: 0.972381
# [169]	training's rmse: 0.950955	valid_1's rmse: 0.971837
# [170]	training's rmse: 0.95013	valid_1's rmse: 0.971358
# [171]	training's rmse: 0.94923	valid_1's rmse: 0.970705
# [172]	training's rmse: 0.948333	valid_1's rmse: 0.97005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	training's rmse: 0.947854	valid_1's rmse: 0.96971
# [174]	training's rmse: 0.947077	valid_1's rmse: 0.969275
# [175]	training's rmse: 0.946308	valid_1's rmse: 0.968823
# [176]	training's rmse: 0.945407	valid_1's rmse: 0.968244
# [177]	training's rmse: 0.944852	valid_1's rmse: 0.967852
# [178]	training's rmse: 0.944135	valid_1's rmse: 0.967429
# [179]	training's rmse: 0.943406	valid_1's rmse: 0.967009
# [180]	training's rmse: 0.942676	valid_1's rmse: 0.966572
# [181]	training's rmse: 0.941908	valid_1's rmse: 0.966146
# [182]	training's rmse: 0.941239	valid_1's rmse: 0.965747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [183]	training's rmse: 0.940599	valid_1's rmse: 0.965371
# [184]	training's rmse: 0.939858	valid_1's rmse: 0.964855
# [185]	training's rmse: 0.93922	valid_1's rmse: 0.964463
# [186]	training's rmse: 0.938502	valid_1's rmse: 0.963998
# [187]	training's rmse: 0.937639	valid_1's rmse: 0.963401
# [188]	training's rmse: 0.936866	valid_1's rmse: 0.962933
# [189]	training's rmse: 0.93604	valid_1's rmse: 0.962393
# [190]	training's rmse: 0.935379	valid_1's rmse: 0.961986
# [191]	training's rmse: 0.934663	valid_1's rmse: 0.961568
# [192]	training's rmse: 0.934099	valid_1's rmse: 0.961236
# [193]	training's rmse: 0.933417	valid_1's rmse: 0.96081
# [194]	training's rmse: 0.932755	valid_1's rmse: 0.960332
# [195]	training's rmse: 0.932127	valid_1's rmse: 0.959862
# [196]	training's rmse: 0.931346	valid_1's rmse: 0.959347
# [197]	training's rmse: 0.930859	valid_1's rmse: 0.959063
# [198]	training's rmse: 0.930233	valid_1's rmse: 0.958726
# [199]	training's rmse: 0.929779	valid_1's rmse: 0.958441
# [200]	training's rmse: 0.928982	valid_1's rmse: 0.957909
# [201]	training's rmse: 0.928207	valid_1's rmse: 0.95739
# [202]	training's rmse: 0.927546	valid_1's rmse: 0.956997
# [203]	training's rmse: 0.927156	valid_1's rmse: 0.956678
# [204]	training's rmse: 0.926335	valid_1's rmse: 0.956066
# [205]	training's rmse: 0.925707	valid_1's rmse: 0.955738
# [206]	training's rmse: 0.924966	valid_1's rmse: 0.955272
# [207]	training's rmse: 0.924316	valid_1's rmse: 0.95484
# [208]	training's rmse: 0.923733	valid_1's rmse: 0.954522
# [209]	training's rmse: 0.923059	valid_1's rmse: 0.954064
# [210]	training's rmse: 0.922462	valid_1's rmse: 0.953754
# [211]	training's rmse: 0.921853	valid_1's rmse: 0.953421
# [212]	training's rmse: 0.921265	valid_1's rmse: 0.953047
# [213]	training's rmse: 0.920601	valid_1's rmse: 0.95256
# [214]	training's rmse: 0.920076	valid_1's rmse: 0.952293
# [215]	training's rmse: 0.9195	valid_1's rmse: 0.951977
# [216]	training's rmse: 0.918984	valid_1's rmse: 0.95169
# [217]	training's rmse: 0.918308	valid_1's rmse: 0.951278
# [218]	training's rmse: 0.917912	valid_1's rmse: 0.951085
# [219]	training's rmse: 0.917337	valid_1's rmse: 0.95076
# [220]	training's rmse: 0.916751	valid_1's rmse: 0.950402
# [221]	training's rmse: 0.9162	valid_1's rmse: 0.950099
# [222]	training's rmse: 0.915633	valid_1's rmse: 0.949767
# [223]	training's rmse: 0.915084	valid_1's rmse: 0.949422
# [224]	training's rmse: 0.914624	valid_1's rmse: 0.949188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [225]	training's rmse: 0.914045	valid_1's rmse: 0.948805
# [226]	training's rmse: 0.913504	valid_1's rmse: 0.94851
# [227]	training's rmse: 0.912837	valid_1's rmse: 0.948055
# [228]	training's rmse: 0.912288	valid_1's rmse: 0.947762
# [229]	training's rmse: 0.91195	valid_1's rmse: 0.947587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [230]	training's rmse: 0.911524	valid_1's rmse: 0.947379
# [231]	training's rmse: 0.910945	valid_1's rmse: 0.947064
# [232]	training's rmse: 0.910436	valid_1's rmse: 0.946788
# [233]	training's rmse: 0.909892	valid_1's rmse: 0.946432
# [234]	training's rmse: 0.909359	valid_1's rmse: 0.946141
# [235]	training's rmse: 0.908935	valid_1's rmse: 0.945889
# [236]	training's rmse: 0.908398	valid_1's rmse: 0.945622
# [237]	training's rmse: 0.9079	valid_1's rmse: 0.945369
# [238]	training's rmse: 0.907427	valid_1's rmse: 0.945153
# [239]	training's rmse: 0.906919	valid_1's rmse: 0.944914
# [240]	training's rmse: 0.906483	valid_1's rmse: 0.944694
# [241]	training's rmse: 0.905871	valid_1's rmse: 0.944288
# [242]	training's rmse: 0.905383	valid_1's rmse: 0.944017
# [243]	training's rmse: 0.904876	valid_1's rmse: 0.943758
# [244]	training's rmse: 0.904193	valid_1's rmse: 0.943296
# [245]	training's rmse: 0.90365	valid_1's rmse: 0.943087
# [246]	training's rmse: 0.903222	valid_1's rmse: 0.942876
# [247]	training's rmse: 0.902818	valid_1's rmse: 0.94266
# [248]	training's rmse: 0.902439	valid_1's rmse: 0.942455
# [249]	training's rmse: 0.901988	valid_1's rmse: 0.942201
# [250]	training's rmse: 0.901403	valid_1's rmse: 0.941825
# [251]	training's rmse: 0.90094	valid_1's rmse: 0.94158
# [252]	training's rmse: 0.900501	valid_1's rmse: 0.941365
# [253]	training's rmse: 0.900012	valid_1's rmse: 0.941118
# [254]	training's rmse: 0.899589	valid_1's rmse: 0.940919
# [255]	training's rmse: 0.899115	valid_1's rmse: 0.940671
# [256]	training's rmse: 0.898644	valid_1's rmse: 0.940442
# [257]	training's rmse: 0.898192	valid_1's rmse: 0.940211
# [258]	training's rmse: 0.897778	valid_1's rmse: 0.939941
# [259]	training's rmse: 0.897379	valid_1's rmse: 0.939737
# [260]	training's rmse: 0.896865	valid_1's rmse: 0.939394
# [261]	training's rmse: 0.896567	valid_1's rmse: 0.939205
# [262]	training's rmse: 0.896086	valid_1's rmse: 0.938814
# [263]	training's rmse: 0.895688	valid_1's rmse: 0.938596
# [264]	training's rmse: 0.89525	valid_1's rmse: 0.938361
# [265]	training's rmse: 0.894878	valid_1's rmse: 0.938144
# [266]	training's rmse: 0.894417	valid_1's rmse: 0.937792
# [267]	training's rmse: 0.894014	valid_1's rmse: 0.937592
# [268]	training's rmse: 0.893597	valid_1's rmse: 0.937396
# [269]	training's rmse: 0.89308	valid_1's rmse: 0.937043
# [270]	training's rmse: 0.892724	valid_1's rmse: 0.93686
# [271]	training's rmse: 0.892287	valid_1's rmse: 0.936662
# [272]	training's rmse: 0.891814	valid_1's rmse: 0.93634
# [273]	training's rmse: 0.891323	valid_1's rmse: 0.936068
# [274]	training's rmse: 0.890859	valid_1's rmse: 0.935783
# [275]	training's rmse: 0.890526	valid_1's rmse: 0.935614
# [276]	training's rmse: 0.890217	valid_1's rmse: 0.935406
# [277]	training's rmse: 0.889787	valid_1's rmse: 0.935162
# [278]	training's rmse: 0.889349	valid_1's rmse: 0.934864
# [279]	training's rmse: 0.888974	valid_1's rmse: 0.934661
# [280]	training's rmse: 0.888626	valid_1's rmse: 0.934452
# [281]	training's rmse: 0.888255	valid_1's rmse: 0.934294
# [282]	training's rmse: 0.887951	valid_1's rmse: 0.934129
# [283]	training's rmse: 0.887614	valid_1's rmse: 0.933984
# [284]	training's rmse: 0.887323	valid_1's rmse: 0.93378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	training's rmse: 0.886967	valid_1's rmse: 0.93359
# [286]	training's rmse: 0.886593	valid_1's rmse: 0.933327
# [287]	training's rmse: 0.886217	valid_1's rmse: 0.933152
# [288]	training's rmse: 0.885798	valid_1's rmse: 0.93287
# [289]	training's rmse: 0.885416	valid_1's rmse: 0.93262
# [290]	training's rmse: 0.885085	valid_1's rmse: 0.932458
# [291]	training's rmse: 0.884723	valid_1's rmse: 0.932267
# [292]	training's rmse: 0.884372	valid_1's rmse: 0.932101
# [293]	training's rmse: 0.883935	valid_1's rmse: 0.931865
# [294]	training's rmse: 0.883493	valid_1's rmse: 0.931619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	training's rmse: 0.883184	valid_1's rmse: 0.931475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	training's rmse: 0.882832	valid_1's rmse: 0.931324
# [297]	training's rmse: 0.882489	valid_1's rmse: 0.93114
# [298]	training's rmse: 0.882008	valid_1's rmse: 0.930869
# [299]	training's rmse: 0.881639	valid_1's rmse: 0.930721
# [300]	training's rmse: 0.881153	valid_1's rmse: 0.930432
# [301]	training's rmse: 0.880714	valid_1's rmse: 0.930185
# [302]	training's rmse: 0.880325	valid_1's rmse: 0.929985
# [303]	training's rmse: 0.880014	valid_1's rmse: 0.929861
# [304]	training's rmse: 0.879659	valid_1's rmse: 0.92968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	training's rmse: 0.879334	valid_1's rmse: 0.929548
# [306]	training's rmse: 0.878892	valid_1's rmse: 0.929266
# [307]	training's rmse: 0.878591	valid_1's rmse: 0.929157
# [308]	training's rmse: 0.878324	valid_1's rmse: 0.929008
# [309]	training's rmse: 0.878109	valid_1's rmse: 0.928919
# [310]	training's rmse: 0.877798	valid_1's rmse: 0.928781
# [311]	training's rmse: 0.877508	valid_1's rmse: 0.928658
# [312]	training's rmse: 0.877182	valid_1's rmse: 0.928509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [313]	training's rmse: 0.876709	valid_1's rmse: 0.928364
# [314]	training's rmse: 0.876424	valid_1's rmse: 0.928228
# [315]	training's rmse: 0.876106	valid_1's rmse: 0.92807
# [316]	training's rmse: 0.875797	valid_1's rmse: 0.927975
# [317]	training's rmse: 0.875453	valid_1's rmse: 0.927809
# [318]	training's rmse: 0.875167	valid_1's rmse: 0.927703
# [319]	training's rmse: 0.874875	valid_1's rmse: 0.927577
# [320]	training's rmse: 0.874576	valid_1's rmse: 0.927453
# [321]	training's rmse: 0.874269	valid_1's rmse: 0.92731
# [322]	training's rmse: 0.874025	valid_1's rmse: 0.927159
# [323]	training's rmse: 0.873832	valid_1's rmse: 0.927055
# [324]	training's rmse: 0.87354	valid_1's rmse: 0.926937
# [325]	training's rmse: 0.873373	valid_1's rmse: 0.926852
# [326]	training's rmse: 0.873177	valid_1's rmse: 0.926755
# [327]	training's rmse: 0.872889	valid_1's rmse: 0.926604
# [328]	training's rmse: 0.872699	valid_1's rmse: 0.92649
# [329]	training's rmse: 0.872301	valid_1's rmse: 0.926314
# [330]	training's rmse: 0.871984	valid_1's rmse: 0.926202
# [331]	training's rmse: 0.87169	valid_1's rmse: 0.926097
# [332]	training's rmse: 0.871422	valid_1's rmse: 0.92596
# [333]	training's rmse: 0.871107	valid_1's rmse: 0.925808
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	training's rmse: 0.870869	valid_1's rmse: 0.925696
# [335]	training's rmse: 0.870578	valid_1's rmse: 0.925569
# [336]	training's rmse: 0.870295	valid_1's rmse: 0.925455
# [337]	training's rmse: 0.870024	valid_1's rmse: 0.925354
# [338]	training's rmse: 0.869772	valid_1's rmse: 0.925253
# [339]	training's rmse: 0.869516	valid_1's rmse: 0.925159
# [340]	training's rmse: 0.869256	valid_1's rmse: 0.925039
# [341]	training's rmse: 0.868968	valid_1's rmse: 0.924897
# [342]	training's rmse: 0.868625	valid_1's rmse: 0.924731
# [343]	training's rmse: 0.868436	valid_1's rmse: 0.924597
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [344]	training's rmse: 0.868192	valid_1's rmse: 0.924495
# [345]	training's rmse: 0.867956	valid_1's rmse: 0.924414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [346]	training's rmse: 0.867737	valid_1's rmse: 0.92433
# [347]	training's rmse: 0.867513	valid_1's rmse: 0.924255
# [348]	training's rmse: 0.86729	valid_1's rmse: 0.924168
# [349]	training's rmse: 0.867013	valid_1's rmse: 0.924035
# [350]	training's rmse: 0.866753	valid_1's rmse: 0.92395
# [351]	training's rmse: 0.866565	valid_1's rmse: 0.923885
# [352]	training's rmse: 0.866251	valid_1's rmse: 0.923648
# [353]	training's rmse: 0.866018	valid_1's rmse: 0.923563
# [354]	training's rmse: 0.865685	valid_1's rmse: 0.923376
# [355]	training's rmse: 0.865483	valid_1's rmse: 0.923285
# [356]	training's rmse: 0.865297	valid_1's rmse: 0.923207
# [357]	training's rmse: 0.865069	valid_1's rmse: 0.923069
# [358]	training's rmse: 0.864828	valid_1's rmse: 0.92297
# [359]	training's rmse: 0.864528	valid_1's rmse: 0.922864
# [360]	training's rmse: 0.864288	valid_1's rmse: 0.922781
# [361]	training's rmse: 0.863929	valid_1's rmse: 0.922575
# [362]	training's rmse: 0.863689	valid_1's rmse: 0.9225
# [363]	training's rmse: 0.863469	valid_1's rmse: 0.922449
# [364]	training's rmse: 0.863285	valid_1's rmse: 0.92237
# [365]	training's rmse: 0.863058	valid_1's rmse: 0.92228
# [366]	training's rmse: 0.862788	valid_1's rmse: 0.922064
# [367]	training's rmse: 0.862576	valid_1's rmse: 0.921988
# [368]	training's rmse: 0.862334	valid_1's rmse: 0.9219
# [369]	training's rmse: 0.862048	valid_1's rmse: 0.921761
# [370]	training's rmse: 0.861688	valid_1's rmse: 0.921543
# [371]	training's rmse: 0.861478	valid_1's rmse: 0.921437
# [372]	training's rmse: 0.861332	valid_1's rmse: 0.921367
# [373]	training's rmse: 0.861096	valid_1's rmse: 0.921172
# [374]	training's rmse: 0.860908	valid_1's rmse: 0.921068
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	training's rmse: 0.860662	valid_1's rmse: 0.921014
# [376]	training's rmse: 0.860432	valid_1's rmse: 0.920928
# [377]	training's rmse: 0.860156	valid_1's rmse: 0.920777
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	training's rmse: 0.859927	valid_1's rmse: 0.920723
# [379]	training's rmse: 0.859708	valid_1's rmse: 0.920628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	training's rmse: 0.859505	valid_1's rmse: 0.920556
# [381]	training's rmse: 0.859167	valid_1's rmse: 0.920357
# [382]	training's rmse: 0.858847	valid_1's rmse: 0.920144
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	training's rmse: 0.858669	valid_1's rmse: 0.92009
# [384]	training's rmse: 0.858451	valid_1's rmse: 0.920006
# [385]	training's rmse: 0.858234	valid_1's rmse: 0.919939
# [386]	training's rmse: 0.858045	valid_1's rmse: 0.919854
# [387]	training's rmse: 0.857756	valid_1's rmse: 0.919651
# [388]	training's rmse: 0.857641	valid_1's rmse: 0.919589
# [389]	training's rmse: 0.857366	valid_1's rmse: 0.919427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [390]	training's rmse: 0.857154	valid_1's rmse: 0.919325
# [391]	training's rmse: 0.856915	valid_1's rmse: 0.919227
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	training's rmse: 0.856659	valid_1's rmse: 0.91907
# [393]	training's rmse: 0.856461	valid_1's rmse: 0.919004
# [394]	training's rmse: 0.856185	valid_1's rmse: 0.91889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [395]	training's rmse: 0.855965	valid_1's rmse: 0.918822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	training's rmse: 0.855712	valid_1's rmse: 0.918718
# [397]	training's rmse: 0.855485	valid_1's rmse: 0.918662
# [398]	training's rmse: 0.855363	valid_1's rmse: 0.918604
# [399]	training's rmse: 0.855145	valid_1's rmse: 0.918478
# [400]	training's rmse: 0.854926	valid_1's rmse: 0.918384
# [401]	training's rmse: 0.854649	valid_1's rmse: 0.918304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [402]	training's rmse: 0.854475	valid_1's rmse: 0.918215
# [403]	training's rmse: 0.854293	valid_1's rmse: 0.918145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [404]	training's rmse: 0.854112	valid_1's rmse: 0.918055
# [405]	training's rmse: 0.85393	valid_1's rmse: 0.917975
# [406]	training's rmse: 0.853731	valid_1's rmse: 0.917904
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [407]	training's rmse: 0.853442	valid_1's rmse: 0.917692
# [408]	training's rmse: 0.85325	valid_1's rmse: 0.917646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [409]	training's rmse: 0.853084	valid_1's rmse: 0.917592
# [410]	training's rmse: 0.852897	valid_1's rmse: 0.917527
# [411]	training's rmse: 0.852711	valid_1's rmse: 0.917502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [412]	training's rmse: 0.852549	valid_1's rmse: 0.917445
# [413]	training's rmse: 0.85227	valid_1's rmse: 0.917284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [414]	training's rmse: 0.852092	valid_1's rmse: 0.917243
# [415]	training's rmse: 0.851981	valid_1's rmse: 0.917178
# [416]	training's rmse: 0.851819	valid_1's rmse: 0.917145
# [417]	training's rmse: 0.851542	valid_1's rmse: 0.916994
# [418]	training's rmse: 0.851353	valid_1's rmse: 0.916905
# [419]	training's rmse: 0.851109	valid_1's rmse: 0.916775
# [420]	training's rmse: 0.85091	valid_1's rmse: 0.916711
# [421]	training's rmse: 0.850721	valid_1's rmse: 0.916633
# [422]	training's rmse: 0.850534	valid_1's rmse: 0.916589
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [423]	training's rmse: 0.850371	valid_1's rmse: 0.916483
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [424]	training's rmse: 0.850209	valid_1's rmse: 0.916445
# [425]	training's rmse: 0.850069	valid_1's rmse: 0.916372
# [426]	training's rmse: 0.849895	valid_1's rmse: 0.91631
# [427]	training's rmse: 0.849626	valid_1's rmse: 0.916186
# [428]	training's rmse: 0.849439	valid_1's rmse: 0.916141
# [429]	training's rmse: 0.849187	valid_1's rmse: 0.915978
# [430]	training's rmse: 0.848948	valid_1's rmse: 0.915919
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [431]	training's rmse: 0.848777	valid_1's rmse: 0.91586
# [432]	training's rmse: 0.848603	valid_1's rmse: 0.915803
# [433]	training's rmse: 0.848406	valid_1's rmse: 0.915758
# [434]	training's rmse: 0.848163	valid_1's rmse: 0.915626
# [435]	training's rmse: 0.847934	valid_1's rmse: 0.91552
# [436]	training's rmse: 0.847771	valid_1's rmse: 0.915459
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [437]	training's rmse: 0.847604	valid_1's rmse: 0.915418
# [438]	training's rmse: 0.847474	valid_1's rmse: 0.915381
# [439]	training's rmse: 0.847328	valid_1's rmse: 0.915323
# [440]	training's rmse: 0.8472	valid_1's rmse: 0.915286
# [441]	training's rmse: 0.847028	valid_1's rmse: 0.915199
# [442]	training's rmse: 0.846869	valid_1's rmse: 0.915149
# [443]	training's rmse: 0.846717	valid_1's rmse: 0.915116
# [444]	training's rmse: 0.846582	valid_1's rmse: 0.91508
# [445]	training's rmse: 0.846454	valid_1's rmse: 0.915059
# [446]	training's rmse: 0.846273	valid_1's rmse: 0.915034
# [447]	training's rmse: 0.846125	valid_1's rmse: 0.914985
# [448]	training's rmse: 0.845961	valid_1's rmse: 0.914933
# [449]	training's rmse: 0.845823	valid_1's rmse: 0.914876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	training's rmse: 0.845719	valid_1's rmse: 0.91484
# [451]	training's rmse: 0.84556	valid_1's rmse: 0.914762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [452]	training's rmse: 0.845427	valid_1's rmse: 0.91471
# [453]	training's rmse: 0.845312	valid_1's rmse: 0.914664
# [454]	training's rmse: 0.845179	valid_1's rmse: 0.914619
# [455]	training's rmse: 0.84501	valid_1's rmse: 0.914594
# [456]	training's rmse: 0.844842	valid_1's rmse: 0.914565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [457]	training's rmse: 0.844685	valid_1's rmse: 0.914536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [458]	training's rmse: 0.844528	valid_1's rmse: 0.914487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [459]	training's rmse: 0.844346	valid_1's rmse: 0.914394
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [460]	training's rmse: 0.844209	valid_1's rmse: 0.914374
# [461]	training's rmse: 0.844105	valid_1's rmse: 0.91434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [462]	training's rmse: 0.843951	valid_1's rmse: 0.914302
# [463]	training's rmse: 0.843828	valid_1's rmse: 0.914263
# [464]	training's rmse: 0.843703	valid_1's rmse: 0.914246
# [465]	training's rmse: 0.843604	valid_1's rmse: 0.914203
# [466]	training's rmse: 0.843455	valid_1's rmse: 0.914186
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [467]	training's rmse: 0.843302	valid_1's rmse: 0.914127
# [468]	training's rmse: 0.843064	valid_1's rmse: 0.914117
# [469]	training's rmse: 0.842811	valid_1's rmse: 0.914052
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [470]	training's rmse: 0.842666	valid_1's rmse: 0.91403
# [471]	training's rmse: 0.842535	valid_1's rmse: 0.913983
# [472]	training's rmse: 0.842418	valid_1's rmse: 0.91397
# [473]	training's rmse: 0.842287	valid_1's rmse: 0.913937
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [474]	training's rmse: 0.842127	valid_1's rmse: 0.913933
# [475]	training's rmse: 0.841955	valid_1's rmse: 0.913898
# [476]	training's rmse: 0.841831	valid_1's rmse: 0.913895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [477]	training's rmse: 0.841743	valid_1's rmse: 0.913873
# [478]	training's rmse: 0.841621	valid_1's rmse: 0.913826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [479]	training's rmse: 0.841548	valid_1's rmse: 0.913802
# [480]	training's rmse: 0.841362	valid_1's rmse: 0.913669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [481]	training's rmse: 0.841246	valid_1's rmse: 0.913648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [482]	training's rmse: 0.841125	valid_1's rmse: 0.913627
# [483]	training's rmse: 0.840982	valid_1's rmse: 0.913591
# [484]	training's rmse: 0.840867	valid_1's rmse: 0.91355
# [485]	training's rmse: 0.840705	valid_1's rmse: 0.913506
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [486]	training's rmse: 0.840559	valid_1's rmse: 0.913415
# [487]	training's rmse: 0.840397	valid_1's rmse: 0.91334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [488]	training's rmse: 0.840273	valid_1's rmse: 0.91332
# [489]	training's rmse: 0.840186	valid_1's rmse: 0.913275
# [490]	training's rmse: 0.840051	valid_1's rmse: 0.913208
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [491]	training's rmse: 0.839976	valid_1's rmse: 0.913157
# [492]	training's rmse: 0.839844	valid_1's rmse: 0.913134
# [493]	training's rmse: 0.839644	valid_1's rmse: 0.913027
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [494]	training's rmse: 0.839531	valid_1's rmse: 0.912995
# [495]	training's rmse: 0.839413	valid_1's rmse: 0.912954
# [496]	training's rmse: 0.839291	valid_1's rmse: 0.912943
# [497]	training's rmse: 0.83909	valid_1's rmse: 0.912815
# [498]	training's rmse: 0.838953	valid_1's rmse: 0.912766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [499]	training's rmse: 0.838808	valid_1's rmse: 0.912723
# [500]	training's rmse: 0.838683	valid_1's rmse: 0.912705
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [501]	training's rmse: 0.838585	valid_1's rmse: 0.912671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [502]	training's rmse: 0.838429	valid_1's rmse: 0.91259
# [503]	training's rmse: 0.838326	valid_1's rmse: 0.91256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [504]	training's rmse: 0.838116	valid_1's rmse: 0.912439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [505]	training's rmse: 0.838012	valid_1's rmse: 0.912383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [506]	training's rmse: 0.837897	valid_1's rmse: 0.912349
# [507]	training's rmse: 0.83782	valid_1's rmse: 0.912326
# [508]	training's rmse: 0.837704	valid_1's rmse: 0.912291
# [509]	training's rmse: 0.837521	valid_1's rmse: 0.912226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [510]	training's rmse: 0.837408	valid_1's rmse: 0.912199
# [511]	training's rmse: 0.837283	valid_1's rmse: 0.912188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [512]	training's rmse: 0.837142	valid_1's rmse: 0.912115
# [513]	training's rmse: 0.837	valid_1's rmse: 0.912047
# [514]	training's rmse: 0.836897	valid_1's rmse: 0.911979
# [515]	training's rmse: 0.836752	valid_1's rmse: 0.911963
# [516]	training's rmse: 0.836616	valid_1's rmse: 0.911939
# [517]	training's rmse: 0.836482	valid_1's rmse: 0.91189
# [518]	training's rmse: 0.836268	valid_1's rmse: 0.911785
# [519]	training's rmse: 0.836064	valid_1's rmse: 0.911753
# [520]	training's rmse: 0.835929	valid_1's rmse: 0.911768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [521]	training's rmse: 0.835796	valid_1's rmse: 0.911718
# [522]	training's rmse: 0.835649	valid_1's rmse: 0.911662
# [523]	training's rmse: 0.835573	valid_1's rmse: 0.911645
# [524]	training's rmse: 0.835463	valid_1's rmse: 0.911604
# [525]	training's rmse: 0.83525	valid_1's rmse: 0.911451
# [526]	training's rmse: 0.83515	valid_1's rmse: 0.911437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [527]	training's rmse: 0.835047	valid_1's rmse: 0.911441
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [528]	training's rmse: 0.834946	valid_1's rmse: 0.911408
# [529]	training's rmse: 0.834756	valid_1's rmse: 0.91131
# [530]	training's rmse: 0.834637	valid_1's rmse: 0.911255
# [531]	training's rmse: 0.834471	valid_1's rmse: 0.911118
# [532]	training's rmse: 0.834354	valid_1's rmse: 0.911109
# [533]	training's rmse: 0.834267	valid_1's rmse: 0.911105
# [534]	training's rmse: 0.834156	valid_1's rmse: 0.91104
# [535]	training's rmse: 0.834051	valid_1's rmse: 0.911012
# [536]	training's rmse: 0.833886	valid_1's rmse: 0.910958
# [537]	training's rmse: 0.833708	valid_1's rmse: 0.910855
# [538]	training's rmse: 0.833569	valid_1's rmse: 0.910846
# [539]	training's rmse: 0.833393	valid_1's rmse: 0.910784
# [540]	training's rmse: 0.833266	valid_1's rmse: 0.910767
# [541]	training's rmse: 0.833135	valid_1's rmse: 0.910757
# [542]	training's rmse: 0.833039	valid_1's rmse: 0.910737
# [543]	training's rmse: 0.832956	valid_1's rmse: 0.91074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [544]	training's rmse: 0.83287	valid_1's rmse: 0.910731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [545]	training's rmse: 0.832766	valid_1's rmse: 0.910693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [546]	training's rmse: 0.832704	valid_1's rmse: 0.910674
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [547]	training's rmse: 0.832551	valid_1's rmse: 0.910644
# [548]	training's rmse: 0.832307	valid_1's rmse: 0.91052
# [549]	training's rmse: 0.832221	valid_1's rmse: 0.910502
# [550]	training's rmse: 0.832103	valid_1's rmse: 0.91048
# [551]	training's rmse: 0.831994	valid_1's rmse: 0.910469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [552]	training's rmse: 0.831878	valid_1's rmse: 0.910459
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [553]	training's rmse: 0.831777	valid_1's rmse: 0.910447
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [554]	training's rmse: 0.831692	valid_1's rmse: 0.910427
# [555]	training's rmse: 0.831572	valid_1's rmse: 0.910417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [556]	training's rmse: 0.831455	valid_1's rmse: 0.910414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [557]	training's rmse: 0.831362	valid_1's rmse: 0.910413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [558]	training's rmse: 0.831262	valid_1's rmse: 0.910404
# [559]	training's rmse: 0.831179	valid_1's rmse: 0.910386
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [560]	training's rmse: 0.831092	valid_1's rmse: 0.91039
# [561]	training's rmse: 0.831008	valid_1's rmse: 0.910363
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [562]	training's rmse: 0.83095	valid_1's rmse: 0.910347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [563]	training's rmse: 0.830841	valid_1's rmse: 0.910346
# [564]	training's rmse: 0.830727	valid_1's rmse: 0.910359
# [565]	training's rmse: 0.830641	valid_1's rmse: 0.910351
# [566]	training's rmse: 0.830522	valid_1's rmse: 0.910347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [567]	training's rmse: 0.830437	valid_1's rmse: 0.910316
# [568]	training's rmse: 0.830305	valid_1's rmse: 0.910256
# [569]	training's rmse: 0.830242	valid_1's rmse: 0.910226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [570]	training's rmse: 0.830069	valid_1's rmse: 0.910168
# [571]	training's rmse: 0.829919	valid_1's rmse: 0.91007
# [572]	training's rmse: 0.829858	valid_1's rmse: 0.910053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [573]	training's rmse: 0.829788	valid_1's rmse: 0.910059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [574]	training's rmse: 0.829706	valid_1's rmse: 0.91005
# [575]	training's rmse: 0.829601	valid_1's rmse: 0.910045
# [576]	training's rmse: 0.829527	valid_1's rmse: 0.910043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [577]	training's rmse: 0.829426	valid_1's rmse: 0.90996
# [578]	training's rmse: 0.829369	valid_1's rmse: 0.909939
# [579]	training's rmse: 0.829233	valid_1's rmse: 0.909883
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [580]	training's rmse: 0.829142	valid_1's rmse: 0.909879
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [581]	training's rmse: 0.829027	valid_1's rmse: 0.909859
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [582]	training's rmse: 0.828852	valid_1's rmse: 0.90979
# [583]	training's rmse: 0.828751	valid_1's rmse: 0.909778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [584]	training's rmse: 0.828679	valid_1's rmse: 0.909765
# [585]	training's rmse: 0.828538	valid_1's rmse: 0.909698
# [586]	training's rmse: 0.828439	valid_1's rmse: 0.909639
# [587]	training's rmse: 0.828263	valid_1's rmse: 0.90958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [588]	training's rmse: 0.828185	valid_1's rmse: 0.909586
# [589]	training's rmse: 0.828034	valid_1's rmse: 0.909548
# [590]	training's rmse: 0.827921	valid_1's rmse: 0.909532
# [591]	training's rmse: 0.827781	valid_1's rmse: 0.909512
# [592]	training's rmse: 0.827519	valid_1's rmse: 0.909342
# [593]	training's rmse: 0.827424	valid_1's rmse: 0.909326
# [594]	training's rmse: 0.82734	valid_1's rmse: 0.909337
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [595]	training's rmse: 0.827208	valid_1's rmse: 0.909255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [596]	training's rmse: 0.827119	valid_1's rmse: 0.909247
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [597]	training's rmse: 0.827003	valid_1's rmse: 0.909234
# [598]	training's rmse: 0.826929	valid_1's rmse: 0.909228
# [599]	training's rmse: 0.826796	valid_1's rmse: 0.909196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's rmse: 0.826735	valid_1's rmse: 0.909206
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [601]	training's rmse: 0.826586	valid_1's rmse: 0.909175
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [602]	training's rmse: 0.826532	valid_1's rmse: 0.909157
# [603]	training's rmse: 0.826356	valid_1's rmse: 0.909115
# [604]	training's rmse: 0.826277	valid_1's rmse: 0.909121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [605]	training's rmse: 0.826136	valid_1's rmse: 0.909078
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [606]	training's rmse: 0.826026	valid_1's rmse: 0.909055
# [607]	training's rmse: 0.825945	valid_1's rmse: 0.909044
# [608]	training's rmse: 0.825861	valid_1's rmse: 0.909036
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [609]	training's rmse: 0.825757	valid_1's rmse: 0.909047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [610]	training's rmse: 0.825675	valid_1's rmse: 0.909066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [611]	training's rmse: 0.825597	valid_1's rmse: 0.909062
# [612]	training's rmse: 0.825492	valid_1's rmse: 0.909052
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [613]	training's rmse: 0.825429	valid_1's rmse: 0.909037
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [614]	training's rmse: 0.825341	valid_1's rmse: 0.909032
# [615]	training's rmse: 0.825249	valid_1's rmse: 0.909004
# [616]	training's rmse: 0.825181	valid_1's rmse: 0.908995
# [617]	training's rmse: 0.825077	valid_1's rmse: 0.908943
# [618]	training's rmse: 0.824964	valid_1's rmse: 0.908872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [619]	training's rmse: 0.824892	valid_1's rmse: 0.908869
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [620]	training's rmse: 0.824823	valid_1's rmse: 0.908866
# [621]	training's rmse: 0.824734	valid_1's rmse: 0.908832
# [622]	training's rmse: 0.824643	valid_1's rmse: 0.90881
# [623]	training's rmse: 0.824549	valid_1's rmse: 0.908802
# [624]	training's rmse: 0.824475	valid_1's rmse: 0.908809
# [625]	training's rmse: 0.824379	valid_1's rmse: 0.908782
# [626]	training's rmse: 0.824298	valid_1's rmse: 0.908775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [627]	training's rmse: 0.824229	valid_1's rmse: 0.908761
# [628]	training's rmse: 0.824157	valid_1's rmse: 0.908741
# [629]	training's rmse: 0.824069	valid_1's rmse: 0.908729
# [630]	training's rmse: 0.823958	valid_1's rmse: 0.908725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [631]	training's rmse: 0.823875	valid_1's rmse: 0.908716
# [632]	training's rmse: 0.823809	valid_1's rmse: 0.908701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [633]	training's rmse: 0.823744	valid_1's rmse: 0.908689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [634]	training's rmse: 0.823643	valid_1's rmse: 0.908659
# [635]	training's rmse: 0.823534	valid_1's rmse: 0.908586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [636]	training's rmse: 0.823474	valid_1's rmse: 0.908599
# [637]	training's rmse: 0.823368	valid_1's rmse: 0.908543
# [638]	training's rmse: 0.823255	valid_1's rmse: 0.908507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [639]	training's rmse: 0.823173	valid_1's rmse: 0.908491
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [640]	training's rmse: 0.823066	valid_1's rmse: 0.908422
# [641]	training's rmse: 0.82299	valid_1's rmse: 0.908427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [642]	training's rmse: 0.822879	valid_1's rmse: 0.90838
# [643]	training's rmse: 0.822779	valid_1's rmse: 0.908383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [644]	training's rmse: 0.822714	valid_1's rmse: 0.908395
# [645]	training's rmse: 0.822558	valid_1's rmse: 0.908279
# [646]	training's rmse: 0.822507	valid_1's rmse: 0.90827
# [647]	training's rmse: 0.822388	valid_1's rmse: 0.908204
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [648]	training's rmse: 0.822292	valid_1's rmse: 0.908215
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [649]	training's rmse: 0.822157	valid_1's rmse: 0.908155
# [650]	training's rmse: 0.822106	valid_1's rmse: 0.908152
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [651]	training's rmse: 0.82205	valid_1's rmse: 0.908153
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [652]	training's rmse: 0.821957	valid_1's rmse: 0.908147
# [653]	training's rmse: 0.821895	valid_1's rmse: 0.908144
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [654]	training's rmse: 0.821847	valid_1's rmse: 0.908141
# [655]	training's rmse: 0.821781	valid_1's rmse: 0.908134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [656]	training's rmse: 0.821703	valid_1's rmse: 0.908151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [657]	training's rmse: 0.821618	valid_1's rmse: 0.908093
# [658]	training's rmse: 0.821533	valid_1's rmse: 0.908082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [659]	training's rmse: 0.821498	valid_1's rmse: 0.908074
# [660]	training's rmse: 0.821418	valid_1's rmse: 0.90805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [661]	training's rmse: 0.821279	valid_1's rmse: 0.90799
# [662]	training's rmse: 0.821197	valid_1's rmse: 0.90798
# [663]	training's rmse: 0.821084	valid_1's rmse: 0.907963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [664]	training's rmse: 0.820974	valid_1's rmse: 0.907956
# [665]	training's rmse: 0.820866	valid_1's rmse: 0.907921
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [666]	training's rmse: 0.820802	valid_1's rmse: 0.907929
# [667]	training's rmse: 0.820731	valid_1's rmse: 0.907934
# [668]	training's rmse: 0.820638	valid_1's rmse: 0.907923
# [669]	training's rmse: 0.820522	valid_1's rmse: 0.907894
# [670]	training's rmse: 0.820468	valid_1's rmse: 0.907895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [671]	training's rmse: 0.82039	valid_1's rmse: 0.9079
# [672]	training's rmse: 0.82032	valid_1's rmse: 0.907921
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [673]	training's rmse: 0.820257	valid_1's rmse: 0.907917
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [674]	training's rmse: 0.820168	valid_1's rmse: 0.907875
# ...
# [3878]	training's rmse: 0.748441	valid_1's rmse: 0.904061
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3879]	training's rmse: 0.748434	valid_1's rmse: 0.904064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3880]	training's rmse: 0.748424	valid_1's rmse: 0.904074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3881]	training's rmse: 0.748417	valid_1's rmse: 0.904078
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3882]	training's rmse: 0.748395	valid_1's rmse: 0.904064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3883]	training's rmse: 0.74839	valid_1's rmse: 0.904068
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3884]	training's rmse: 0.748379	valid_1's rmse: 0.904061
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3885]	training's rmse: 0.748373	valid_1's rmse: 0.904057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3886]	training's rmse: 0.748368	valid_1's rmse: 0.904061
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3887]	training's rmse: 0.748361	valid_1's rmse: 0.90407
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3888]	training's rmse: 0.748355	valid_1's rmse: 0.904072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3889]	training's rmse: 0.748348	valid_1's rmse: 0.904086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3890]	training's rmse: 0.74834	valid_1's rmse: 0.904088
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3891]	training's rmse: 0.748335	valid_1's rmse: 0.904089
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3892]	training's rmse: 0.748329	valid_1's rmse: 0.904088
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3893]	training's rmse: 0.748321	valid_1's rmse: 0.904073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3894]	training's rmse: 0.748314	valid_1's rmse: 0.904073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3895]	training's rmse: 0.748308	valid_1's rmse: 0.904066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3896]	training's rmse: 0.748298	valid_1's rmse: 0.904061
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3897]	training's rmse: 0.748292	valid_1's rmse: 0.904059
# [3898]	training's rmse: 0.748282	valid_1's rmse: 0.904061
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3899]	training's rmse: 0.748271	valid_1's rmse: 0.904057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3900]	training's rmse: 0.748263	valid_1's rmse: 0.904056
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3901]	training's rmse: 0.748258	valid_1's rmse: 0.904058
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3902]	training's rmse: 0.748252	valid_1's rmse: 0.90406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3903]	training's rmse: 0.748246	valid_1's rmse: 0.904066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3904]	training's rmse: 0.748239	valid_1's rmse: 0.904063
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3905]	training's rmse: 0.748236	valid_1's rmse: 0.904064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3906]	training's rmse: 0.748224	valid_1's rmse: 0.904076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3907]	training's rmse: 0.748213	valid_1's rmse: 0.904078
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3908]	training's rmse: 0.748202	valid_1's rmse: 0.904076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3909]	training's rmse: 0.748196	valid_1's rmse: 0.904077
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3910]	training's rmse: 0.74819	valid_1's rmse: 0.904076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3911]	training's rmse: 0.748182	valid_1's rmse: 0.90409
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3912]	training's rmse: 0.748173	valid_1's rmse: 0.904084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3913]	training's rmse: 0.748169	valid_1's rmse: 0.904084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3914]	training's rmse: 0.748164	valid_1's rmse: 0.904164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3915]	training's rmse: 0.748156	valid_1's rmse: 0.904166
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3916]	training's rmse: 0.74814	valid_1's rmse: 0.904163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3917]	training's rmse: 0.748133	valid_1's rmse: 0.904167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3918]	training's rmse: 0.748124	valid_1's rmse: 0.904174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3919]	training's rmse: 0.748116	valid_1's rmse: 0.904176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3920]	training's rmse: 0.748107	valid_1's rmse: 0.904171
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3921]	training's rmse: 0.7481	valid_1's rmse: 0.904169
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3922]	training's rmse: 0.748095	valid_1's rmse: 0.904165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3923]	training's rmse: 0.748088	valid_1's rmse: 0.904163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3924]	training's rmse: 0.748058	valid_1's rmse: 0.904172
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3925]	training's rmse: 0.74804	valid_1's rmse: 0.904166
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3926]	training's rmse: 0.748034	valid_1's rmse: 0.904165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3927]	training's rmse: 0.748018	valid_1's rmse: 0.90417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3928]	training's rmse: 0.748008	valid_1's rmse: 0.904181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3929]	training's rmse: 0.748001	valid_1's rmse: 0.90418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3930]	training's rmse: 0.747992	valid_1's rmse: 0.90418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3931]	training's rmse: 0.747985	valid_1's rmse: 0.904179
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3932]	training's rmse: 0.747972	valid_1's rmse: 0.904173
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3933]	training's rmse: 0.747968	valid_1's rmse: 0.904172
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3934]	training's rmse: 0.747961	valid_1's rmse: 0.904196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3935]	training's rmse: 0.747955	valid_1's rmse: 0.904193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3936]	training's rmse: 0.747949	valid_1's rmse: 0.904196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3937]	training's rmse: 0.747945	valid_1's rmse: 0.904192
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3938]	training's rmse: 0.747936	valid_1's rmse: 0.904196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3939]	training's rmse: 0.74793	valid_1's rmse: 0.904188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3940]	training's rmse: 0.747927	valid_1's rmse: 0.90419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3941]	training's rmse: 0.747919	valid_1's rmse: 0.904188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3942]	training's rmse: 0.747911	valid_1's rmse: 0.904201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3943]	training's rmse: 0.747903	valid_1's rmse: 0.904195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3944]	training's rmse: 0.747895	valid_1's rmse: 0.904191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3945]	training's rmse: 0.747886	valid_1's rmse: 0.904194
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3946]	training's rmse: 0.747876	valid_1's rmse: 0.904195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3947]	training's rmse: 0.747867	valid_1's rmse: 0.904203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3948]	training's rmse: 0.747847	valid_1's rmse: 0.904222
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3949]	training's rmse: 0.74784	valid_1's rmse: 0.904226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3950]	training's rmse: 0.747831	valid_1's rmse: 0.904223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3951]	training's rmse: 0.747825	valid_1's rmse: 0.904224
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3952]	training's rmse: 0.74782	valid_1's rmse: 0.904222
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3953]	training's rmse: 0.747806	valid_1's rmse: 0.904235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3954]	training's rmse: 0.7478	valid_1's rmse: 0.904233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3955]	training's rmse: 0.747793	valid_1's rmse: 0.90424
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3956]	training's rmse: 0.747782	valid_1's rmse: 0.904243
# [3957]	training's rmse: 0.747753	valid_1's rmse: 0.904244
# [3958]	training's rmse: 0.747699	valid_1's rmse: 0.904281
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3959]	training's rmse: 0.747696	valid_1's rmse: 0.904284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3960]	training's rmse: 0.747691	valid_1's rmse: 0.904282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3961]	training's rmse: 0.747683	valid_1's rmse: 0.904288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3962]	training's rmse: 0.747677	valid_1's rmse: 0.904285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3963]	training's rmse: 0.747668	valid_1's rmse: 0.904284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3964]	training's rmse: 0.747656	valid_1's rmse: 0.904281
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3965]	training's rmse: 0.747646	valid_1's rmse: 0.904276
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3966]	training's rmse: 0.747639	valid_1's rmse: 0.904277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3967]	training's rmse: 0.747635	valid_1's rmse: 0.904277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3968]	training's rmse: 0.747622	valid_1's rmse: 0.904292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3969]	training's rmse: 0.747616	valid_1's rmse: 0.904294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3970]	training's rmse: 0.747608	valid_1's rmse: 0.904294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3971]	training's rmse: 0.747601	valid_1's rmse: 0.90429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3972]	training's rmse: 0.747593	valid_1's rmse: 0.904289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3973]	training's rmse: 0.747585	valid_1's rmse: 0.90429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3974]	training's rmse: 0.747578	valid_1's rmse: 0.904289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3975]	training's rmse: 0.747569	valid_1's rmse: 0.904289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3976]	training's rmse: 0.747566	valid_1's rmse: 0.904289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3977]	training's rmse: 0.74756	valid_1's rmse: 0.90429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3978]	training's rmse: 0.747555	valid_1's rmse: 0.904288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3979]	training's rmse: 0.747548	valid_1's rmse: 0.904284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3980]	training's rmse: 0.747538	valid_1's rmse: 0.90429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3981]	training's rmse: 0.74753	valid_1's rmse: 0.904288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3982]	training's rmse: 0.74752	valid_1's rmse: 0.904289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3983]	training's rmse: 0.747507	valid_1's rmse: 0.90428
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3984]	training's rmse: 0.747502	valid_1's rmse: 0.904282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3985]	training's rmse: 0.747496	valid_1's rmse: 0.904282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3986]	training's rmse: 0.74749	valid_1's rmse: 0.904281
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3987]	training's rmse: 0.747483	valid_1's rmse: 0.904282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3988]	training's rmse: 0.747462	valid_1's rmse: 0.904295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3989]	training's rmse: 0.747455	valid_1's rmse: 0.904292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3990]	training's rmse: 0.74745	valid_1's rmse: 0.904293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3991]	training's rmse: 0.747445	valid_1's rmse: 0.904293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3992]	training's rmse: 0.747435	valid_1's rmse: 0.904292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3993]	training's rmse: 0.747427	valid_1's rmse: 0.904296
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3994]	training's rmse: 0.747419	valid_1's rmse: 0.904299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3995]	training's rmse: 0.747406	valid_1's rmse: 0.904292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3996]	training's rmse: 0.747397	valid_1's rmse: 0.904295
# [3997]	training's rmse: 0.747385	valid_1's rmse: 0.904294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3998]	training's rmse: 0.747372	valid_1's rmse: 0.904293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3999]	training's rmse: 0.747364	valid_1's rmse: 0.9043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4000]	training's rmse: 0.747349	valid_1's rmse: 0.904308

# %%
lgb_model.feature_importance
# Out:
# <bound method Booster.feature_importance of <lightgbm.basic.Booster object at 0x0000020D5F1EDE48>>

# %%
for i in lgb_model.feature_importance:
    ic(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-e36212d653f5> in <module>
# ----> 1 for i in lgb_model.feature_importance:
#       2     ic(i)
#
# TypeError: 'method' object is not iterable

# %% [markdown]
# # 验证

# %%
from sklearn.metrics import mean_squared_error
valid_prediction = lgb_model.predict(X_valid).clip(0,20)
rmse_valid = np.sqrt(mean_squared_error(valid_prediction, label_valid))
rmse_valid
# Out:
# 0.9152593281871978

# %%
# test数据
testData = matrix[matrix['date_block_num'] == 34]
X_test = testData.drop('item_cnt_month', axis=1)

# 预测&生成文件
y_test = lgb_model.predict(X_test).clip(0, 20)
submission = pd.DataFrame({ 'ID': range(0, 214200), 'item_cnt_month': y_test})

test0 = test[test.item_id.isin(six_zero_item_id)]
ids = list(test0.ID.values)
submission.loc[submission.ID.isin(ids), 'item_cnt_month'] = 0.0
submission.to_csv('./submit/sub12.csv', index=False)
