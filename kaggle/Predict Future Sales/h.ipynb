# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from icecream import ic
from sklearn.preprocessing import LabelEncoder
import time
from itertools import product
from icecream import ic


plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

sales_train = pd.read_csv('./data/sales_train.csv')
test = pd.read_csv('./data/test.csv')   # (214200, 3)

# 计算每个商品每个月的销售量，假如某个商品在某个月没有数据，则填充0（即这个月的销售量为0）
sales_by_item_id = sales_train.pivot_table(index=['item_id'], values=['item_cnt_day'], columns='date_block_num', aggfunc=np.sum, fill_value=0).reset_index()
sales_by_item_id.columns = sales_by_item_id.columns.droplevel().map(str)
sales_by_item_id.columns.values[0] = 'item_id'
sales_by_item_id = sales_by_item_id.rename_axis(None, axis=1)

# 获取最近6个月销售量为0的数据
six_zero = sales_by_item_id[(sales_by_item_id['28'] == 0) & (sales_by_item_id['29'] == 0) & (sales_by_item_id['30'] == 0) & (sales_by_item_id['31'] == 0) & (sales_by_item_id['32'] == 0) & (sales_by_item_id['33'] == 0)]
six_zero_item_id = list(six_zero['item_id'].values)   # item_id列表
# test.loc[test.item_id.isin(six_zero_item_id), 'item_cnt_month'] = 0  # 将test数据中（最近六个月销量为0）的数据月销量设为0，有7812个

# 计算每个商店每个月的销量
sales_by_shop_id = sales_train.pivot_table(index=['shop_id'], values=['item_cnt_day'], aggfunc=np.sum, fill_value=0, columns='date_block_num').reset_index()
sales_by_shop_id.columns = sales_by_shop_id.columns.droplevel().map(str)    # 将两层column转化为一层column,保留下层column
sales_by_shop_id.columns.values[0] = 'shop_id'
sales_by_shop_id = sales_by_shop_id.rename_axis(None, axis=1)   # 将列方向的轴重命名为none

# zero = sales_train[sales_train.date_block_num==0]
# ic(zero.shop_id.unique(), len(zero.item_id.unique()), len(zero.shop_id.unique()), len(zero.shop_id.unique()) * len(zero.item_id.unique()))
# ic(sales_train.shop_id.unique(), len(sales_train.item_id.unique()), len(sales_train.shop_id.unique()), len(sales_train.shop_id.unique()) * len(sales_train.item_id.unique()))

"""组合date_block_num,shop_id,item_id(部分) 总量：10913850"""
matrix = []
cols = ['date_block_num','shop_id','item_id']
for i in range(34):
    sales = sales_train[sales_train.date_block_num==i]
    matrix.append(np.array(list(product([i], sales.shop_id.unique(), sales.item_id.unique())), dtype='int16'))
matrix = pd.DataFrame(np.vstack(matrix), columns=cols)
matrix['date_block_num'] = matrix['date_block_num'].astype(np.int8)
matrix['shop_id'] = matrix['shop_id'].astype(np.int8)
matrix.sort_values(cols, inplace=True)  # 排序
sales_train['revenue'] = sales_train['item_price'] * sales_train['item_cnt_day']    # 某一天的销售额

# 分组
groupby = sales_train.groupby(['shop_id','item_id','date_block_num']).agg({'item_cnt_day': 'sum'}).reset_index()
groupby = groupby.rename(columns={'item_cnt_day': 'item_cnt_month'})
matrix = matrix.merge(groupby, on=['date_block_num','shop_id','item_id'], how='left')
matrix['item_cnt_month'] = matrix['item_cnt_month'].fillna(0).clip(0, 20)
matrix['item_cnt_month'] = matrix['item_cnt_month'].astype(np.float16)

# test数据
test['date_block_num'] = 34
test['date_block_num'] = test['date_block_num'].astype(np.int8)
test['shop_id'] = test['shop_id'].astype(np.int8)
test['item_id'] = test['item_id'].astype(np.int16)

# 合并matrix,test
matrix = pd.concat([matrix, test[cols]], ignore_index=True, axis=0)
matrix['item_cnt_month'].fillna(0, inplace=True)

# 商品信息
items = pd.read_csv('./data/items.csv')
items = items[['item_id', 'item_category_id']]
matrix = pd.merge(left=matrix, right=items, on='item_id', how='left')  # 合并

# 商品类别
le = LabelEncoder()
categories = pd.read_csv('./data/item_categories.csv')
categories['split'] = categories['item_category_name'].str.split('-')
categories['type'] = categories['split'].map(lambda x:x[0].strip())
categories['subtype'] = categories['split'].map(lambda x:x[1].strip() if len(x)>1 else x[0].strip())
categories = categories[['item_category_id','type','subtype']]
categories['cat_type_code'] = le.fit_transform(categories['type'])
categories['cat_subtype_code'] = le.fit_transform(categories['subtype'])
matrix = pd.merge(left=matrix, right=categories[['item_category_id','cat_type_code','cat_subtype_code']], on='item_category_id', how='left')    # 合并

# 商店信息
shops = pd.read_csv('./data/shops.csv')
shops['split']=shops.shop_name.str.split(' ')
shops['shop_city'] = shops['split'].map(lambda x:x[0])
shops['shop_city_code'] = le.fit_transform(shops['shop_city'])

def st(name):
    ic(name)
    if 'ТЦ' in name or 'ТРЦ' in name:
        shopt = 'ТЦ'
    elif 'ТК' in name:
        shopt = 'ТК'
    elif 'ТРК' in name:
        shopt = 'ТРК'
    elif 'МТРЦ' in name:
        shopt = 'МТРЦ'
    else:
        shopt = 'UNKNOWN'
    return shopt
shops['shop_type'] = shops['shop_name'].apply(st)

shops.loc[shops.shop_id == 21, 'shop_type'] = 'МТРЦ'   # 修正
shops['shop_type_code'] = le.fit_transform(shops['shop_type'])
matrix = pd.merge(left=matrix, right=shops[['shop_id','shop_city_code','shop_type_code']], on='shop_id', how='left')    # 合并
matrix['item_category_id'] = matrix['item_category_id'].astype(np.int8)
matrix['cat_type_code'] = matrix['cat_type_code'].astype(np.int8)
matrix['cat_subtype_code'] = matrix['cat_subtype_code'].astype(np.int8)
matrix['shop_city_code'] = matrix['shop_city_code'].astype(np.int8)
matrix['shop_type_code'] = matrix['shop_type_code'].astype(np.int8)


"""历史信息"""

def lag_features(df, lags, col):
    tmp = df[['date_block_num','shop_id','item_id',col]]
    for i in lags:
        shifted = tmp.copy()
        shifted.columns = ['date_block_num','shop_id','item_id',col+'_lag_'+str(i)]
        shifted['date_block_num'] = shifted['date_block_num'] + i
        df = pd.merge(left=df, right=shifted, on=['date_block_num','shop_id','item_id'], how='left')
    return df

matrix = lag_features(matrix, [1,2,3,6,12], 'item_cnt_month')

# 月销量（所有商品）
group = matrix.groupby('date_block_num').agg({'item_cnt_month': 'mean'}).reset_index()
group.columns = ['date_block_num', 'date_avg_item_cnt']
matrix = pd.merge(left=matrix, right=group, on='date_block_num', how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_avg_item_cnt')
matrix.drop('date_avg_item_cnt', axis=1, inplace=True)

# 月销量（每一件商品）
group = matrix.groupby(['date_block_num', 'item_id']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_item_avg_item_cnt' ]
group.reset_index(inplace=True)
matrix = pd.merge(left=matrix, right=group, on=['date_block_num','item_id'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_item_avg_item_cnt')
matrix.drop('date_item_avg_item_cnt', axis=1, inplace=True)

# 月销量（每个商店 ）
group = matrix.groupby(['date_block_num','shop_id']).agg({'item_cnt_month': 'mean'})
group.columns = ['date_shop_avg_item_cnt']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on=['date_block_num','shop_id'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_shop_avg_item_cnt')
matrix.drop('date_shop_avg_item_cnt', axis=1, inplace=True)

# 月销量（每个类别）
group = matrix.groupby(['date_block_num','item_category_id']).agg({'item_cnt_month': 'mean'})
group.columns = ['date_cat_avg_item_cnt']
group = group.reset_index()
matrix=pd.merge(left=matrix, right=group, on=['date_block_num','item_category_id'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_cat_avg_item_cnt')
matrix.drop('date_cat_avg_item_cnt', axis=1, inplace=True)

# 月销量（商品类别-商店）
group = matrix.groupby(['date_block_num','item_category_id','shop_id']).agg({'item_cnt_month': 'mean'})
group.columns = ['date_cat_shop_avg_item_cnt']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on=['date_block_num','item_category_id','shop_id'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_cat_shop_avg_item_cnt')
matrix.drop('date_cat_shop_avg_item_cnt', axis=1, inplace=True)

# 月销量（商品大类）
group = matrix.groupby(['date_block_num','cat_type_code']).agg({'item_cnt_month': 'mean'})
group.columns = ['date_type_avg_item_cnt']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on=['date_block_num','cat_type_code'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_type_avg_item_cnt')
matrix.drop('date_type_avg_item_cnt', axis=1, inplace=True)

# # 月销量（商品-商品大类） ++++++++++++ 和 月销量（商品）是重复的，因为每一个商品，类别是确定的，大类也是确定的
# group = matrix.groupby(['date_block_num', 'item_id', 'cat_type_code']).agg({'item_cnt_month': ['mean']})
# group.columns = ['date_item_type_avg_item_cnt']
# group = group.reset_index()
# matrix = pd.merge(left=matrix, right=group, on=['date_block_num', 'item_id', 'cat_type_code'], how='left')
# matrix = lag_features(matrix, [1,2,3,6,12], 'date_item_type_avg_item_cnt')
# matrix.drop('date_item_type_avg_item_cnt', axis=1, inplace=True)

# 月销量（商店城市）
group = matrix.groupby(['date_block_num','shop_city_code']).agg({'item_cnt_month': 'mean'})
group.columns = ['date_city_avg_item_cnt']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on=['date_block_num','shop_city_code'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_city_avg_item_cnt')
matrix.drop('date_city_avg_item_cnt', axis=1, inplace=True)

# 月销量（商品-商店城市）
group = matrix.groupby(['date_block_num', 'item_id', 'shop_city_code']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_item_city_avg_item_cnt']
group = group.reset_index()
matrix=pd.merge(left=matrix, right=group, on=['date_block_num', 'item_id', 'shop_city_code'], how='left')
matrix = lag_features(matrix, [1,2,3,6,12], 'date_item_city_avg_item_cnt')
matrix.drop('date_item_city_avg_item_cnt', axis=1, inplace=True)

# 趋势特征
group = sales_train.groupby('item_id').agg({'item_price': 'mean'})
group.columns = ['item_avg_item_price']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on='item_id', how='left')

group = sales_train.groupby(['date_block_num','item_id']).agg({'item_price': 'mean'})
group.columns = ['date_item_avg_item_price']
group = group.reset_index()
matrix=pd.merge(left=matrix, right=group, on=['date_block_num','item_id'], how='left')

matrix['item_avg_item_price'] = matrix['item_avg_item_price'].astype(np.float16)
matrix['date_item_avg_item_price'] = matrix['date_item_avg_item_price'].astype(np.float16)

# 计算matrix中商品的历史价格
lags = [1,2,3,4,5,6,12]
matrix = lag_features(matrix, lags, 'date_item_avg_item_price')
for i in lags:
    matrix['delta_price_lag_'+str(i)]=(matrix['date_item_avg_item_price_lag_' + str(i)] - matrix['item_avg_item_price']) / matrix['item_avg_item_price']

def select_trend(row):
    for i in lags:
        if pd.notnull(row['delta_price_lag_'+str(i)]):  # 如果不是NaN
            return row['delta_price_lag_'+str(i)]
    return 0

matrix['delta_price_lag']=matrix.apply(select_trend, axis=1)
matrix['delta_price_lag'] = matrix['delta_price_lag'].astype(np.float16)

features_to_drop = ['item_avg_item_price','date_item_avg_item_price']
for i in lags:
    features_to_drop += ['date_item_avg_item_price_lag_'+str(i)]
    features_to_drop += ['delta_price_lag_'+str(i)]
matrix.drop(features_to_drop, axis=1, inplace=True)

# 每个月的天数
matrix['month'] = matrix['date_block_num'] % 12
days = pd.Series([31,28,31,30,31,30,31,31,30,31,30,31])
matrix['days'] = matrix['month'].map(days)
matrix['days'] = matrix['days'].astype(np.int8)

# 开始销量
matrix['item_shop_first_sale'] = matrix['date_block_num'] - matrix.groupby(['item_id','shop_id'])['date_block_num'].transform('min')
matrix['item_first_sale'] = matrix['date_block_num'] - matrix.groupby('item_id')['date_block_num'].transform('min')
# Out:
# ic| name: '!Якутск Орджоникидзе, 56 фран'
# ic| name: '!Якутск ТЦ "Центральный" фран'
# ic| name: 'Адыгея ТЦ "Мега"'
# ic| name: 'Балашиха ТРК "Октябрь-Киномир"'
# ic| name: 'Волжский ТЦ "Волга Молл"'
# ic| name: 'Вологда ТРЦ "Мармелад"'
# ic| name: 'Воронеж (Плехановская, 13)'
# ic| name: 'Воронеж ТРЦ "Максимир"'
# ic| name: 'Воронеж ТРЦ Сити-Парк "Град"'
# ic| name: 'Выездная Торговля'
# ic| name: 'Жуковский ул. Чкалова 39м?'
# ic| name: 'Жуковский ул. Чкалова 39м²'
# ic| name: 'Интернет-магазин ЧС'
# ic| name: 'Казань ТЦ "Бехетле"'
# ic| name: 'Казань ТЦ "ПаркХаус" II'
# ic| name: 'Калуга ТРЦ "XXI век"'
# ic| name: 'Коломна ТЦ "Рио"'
# ic| name: 'Красноярск ТЦ "Взлетка Плаза"'
# ic| name: 'Красноярск ТЦ "Июнь"'
# ic| name: 'Курск ТЦ "Пушкинский"'
# ic| name: 'Москва "Распродажа"'
# ic| name: 'Москва МТРЦ "Афи Молл"'
# ic| name: 'Москва Магазин С21'
# ic| name: 'Москва ТК "Буденовский" (пав.А2)'
# ic| name: 'Москва ТК "Буденовский" (пав.К7)'
# ic| name: 'Москва ТРК "Атриум"'
# ic| name: 'Москва ТЦ "Ареал" (Беляево)'
# ic| name: 'Москва ТЦ "МЕГА Белая Дача II"'
# ic| name: 'Москва ТЦ "МЕГА Теплый Стан" II'
# ic| name: 'Москва ТЦ "Новый век" (Новокосино)'
# ic| name: 'Москва ТЦ "Перловский"'
# ic| name: 'Москва ТЦ "Семеновский"'
# ic| name: 'Москва ТЦ "Серебряный Дом"'
# ic| name: 'Мытищи ТРК "XL-3"'
# ic| name: 'Н.Новгород ТРЦ "РИО"'
# ic| name: 'Н.Новгород ТРЦ "Фантастика"'
# ic| name: 'Новосибирск ТРЦ "Галерея Новосибирск"'
# ic| name: 'Новосибирск ТЦ "Мега"'
# ic| name: 'Омск ТЦ "Мега"'
# ic| name: 'РостовНаДону ТРК "Мегацентр Горизонт"'
# ic| name: 'РостовНаДону ТРК "Мегацентр Горизонт" Островной'
# ic| name: 'РостовНаДону ТЦ "Мега"'
# ic| name: 'СПб ТК "Невский Центр"'
# ic| name: 'СПб ТК "Сенная"'
# ic| name: 'Самара ТЦ "Мелодия"'
# ic| name: 'Самара ТЦ "ПаркХаус"'
# ic| name: 'Сергиев Посад ТЦ "7Я"'
# ic| name: 'Сургут ТРЦ "Сити Молл"'
# ic| name: 'Томск ТРЦ "Изумрудный Город"'
# ic| name: 'Тюмень ТРЦ "Кристалл"'
# ic| name: 'Тюмень ТЦ "Гудвин"'
# ic| name: 'Тюмень ТЦ "Зеленый Берег"'
# ic| name: 'Уфа ТК "Центральный"'
# ic| name: 'Уфа ТЦ "Семья" 2'
# ic| name: 'Химки ТЦ "Мега"'
# ic| name: 'Цифровой склад 1С-Онлайн'
# ic| name: 'Чехов ТРЦ "Карнавал"'
# ic| name: 'Якутск Орджоникидзе, 56'
# ic| name: 'Якутск ТЦ "Центральный"'
# ic| name: 'Ярославль ТЦ "Альтаир"'

# %%
import lightgbm as lgb

# %%
matrix.shape
# Out:
# (6639294, 60)

# %%
# matrix_11128050_59_bak = matrix.copy()

# %%
matrix = matrix_11128050_59_bak.copy()

# %%
matrix.shape
# Out:
# (11128050, 59)

# %%
# **********趋势特征 delta2_cnt_month_lag ********************
group = matrix.groupby(['shop_id', 'item_id']).agg({'item_cnt_month': 'mean'})
group.columns = ['qushi_shop_item_avg_cnt_month']
group = group.reset_index()
matrix = pd.merge(left=matrix, right=group, on=['shop_id', 'item_id'], how='left')

group = matrix.groupby(['date_block_num', 'shop_id', 'item_id']).agg({'item_cnt_month': 'mean'})
group.columns = ['qushi_date_shop_item_avg_cnt_month']
group = group.reset_index()
matrix=pd.merge(left=matrix, right=group, on=['date_block_num', 'shop_id', 'item_id'], how='left')

# 计算matrix中商品的历史价格
lags = [1,2,3,4,5,6,12]
matrix = lag_features(matrix, lags, 'qushi_date_shop_item_avg_cnt_month')
for i in lags:
    matrix['delta2_cnt_month_lag_'+str(i)] = (matrix['qushi_date_shop_item_avg_cnt_month_lag_' + str(i)] - matrix['qushi_shop_item_avg_cnt_month']) / matrix['qushi_shop_item_avg_cnt_month']

def select_trend3(row):
    for i in lags:
        if pd.notnull(row['delta2_cnt_month_lag_'+str(i)]):  # 如果不是NaN
            return row['delta2_cnt_month_lag_'+str(i)]
    return 0   #  如果delta_price_lag_都为空，那么将趋势设为0，0代表没有趋势

matrix['delta2_cnt_month_lag'] = matrix.apply(select_trend3, axis=1)
matrix['delta2_cnt_month_lag'] = matrix['delta2_cnt_month_lag'].astype(np.float16)

features_to_drop = ['qushi_shop_item_avg_cnt_month','qushi_date_shop_item_avg_cnt_month']
for i in lags:
    features_to_drop += ['qushi_date_shop_item_avg_cnt_month_lag_'+str(i)]
    features_to_drop += ['delta2_cnt_month_lag_'+str(i)]
matrix.drop(features_to_drop, axis=1, inplace=True)

# %%
matrix.shape
# Out:
# (11128050, 59)

# %%
# 因为有12个月的延迟特征（1，2，3，6，12）（1，2，3，4，5，6，12），所以需要删除前12月的数据
matrix = matrix[matrix.date_block_num > 11]

# 找到有NaN值的列，然后把那些列中的NaN值填充0
def fill_na(df):
    for col in df.columns:
        if ('_lag_' in col) & (df[col].isnull().any()):
            if ('item_cnt' in col):
                df[col].fillna(0, inplace=True)         
    return df

matrix = fill_na(matrix)

# %%
matrix.shape
# Out:
# (6639294, 59)

# %% [markdown]
# # 训练

# %%
"""建模"""
trainData = matrix[matrix['date_block_num'] < 33]
label_train = trainData['item_cnt_month']
X_train = trainData.drop('item_cnt_month', axis=1)

validData = matrix[matrix['date_block_num'] == 33]
label_valid = validData['item_cnt_month']
X_valid = validData.drop('item_cnt_month', axis=1)

# %%
train_data = lgb.Dataset(data=X_train, label=label_train)
valid_data = lgb.Dataset(data=X_valid, label=label_valid)
params = {
    'objective': 'regression',  # 回归
    'metric': 'rmse',   # 回归问题选择rmse
    'n_estimators': 1000,
    'max_depth': 8,
    'num_leaves': 200,   # 每个弱学习器拥有的叶子的数量
    'learning_rate': 0.01,
    'bagging_fraction': 0.9,    # 每次训练“弱学习器”用的数据比例（应该也是随机的），用于加快训练速度和减小过拟合
    'feature_fraction': 0.3,   # 每次迭代过程中，随机选择30%的特征建树（弱学习器）
    'bagging_seed': 0,
    'early_stop_rounds': 50
}
lgb_model = lgb.train(params, train_data, valid_sets=[train_data, valid_data])
# Out:
# [LightGBM] [Warning] Unknown parameter: early_stop_rounds
# [LightGBM] [Warning] Unknown parameter: early_stop_rounds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.237215 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9530
# [LightGBM] [Info] Number of data points in the train set: 6186922, number of used features: 58
# [LightGBM] [Warning] Unknown parameter: early_stop_rounds
# [LightGBM] [Info] Start training from score 0.288852
# [1]	training's rmse: 1.18425	valid_1's rmse: 1.13338
# [2]	training's rmse: 1.17976	valid_1's rmse: 1.13011
# [3]	training's rmse: 1.17546	valid_1's rmse: 1.12713
# [4]	training's rmse: 1.17052	valid_1's rmse: 1.12329
# [5]	training's rmse: 1.1668	valid_1's rmse: 1.12058
# [6]	training's rmse: 1.16227	valid_1's rmse: 1.11729
# [7]	training's rmse: 1.15891	valid_1's rmse: 1.11487
# [8]	training's rmse: 1.15433	valid_1's rmse: 1.11151
# [9]	training's rmse: 1.15038	valid_1's rmse: 1.10895
# [10]	training's rmse: 1.14709	valid_1's rmse: 1.10668
# [11]	training's rmse: 1.14398	valid_1's rmse: 1.10422
# [12]	training's rmse: 1.14004	valid_1's rmse: 1.10131
# [13]	training's rmse: 1.13534	valid_1's rmse: 1.0978
# [14]	training's rmse: 1.13111	valid_1's rmse: 1.09471
# [15]	training's rmse: 1.12695	valid_1's rmse: 1.09166
# [16]	training's rmse: 1.12313	valid_1's rmse: 1.08896
# [17]	training's rmse: 1.11934	valid_1's rmse: 1.08627
# [18]	training's rmse: 1.11548	valid_1's rmse: 1.08353
# [19]	training's rmse: 1.11237	valid_1's rmse: 1.08132
# [20]	training's rmse: 1.10932	valid_1's rmse: 1.07914
# [21]	training's rmse: 1.1059	valid_1's rmse: 1.07678
# [22]	training's rmse: 1.1035	valid_1's rmse: 1.07508
# [23]	training's rmse: 1.10072	valid_1's rmse: 1.07314
# [24]	training's rmse: 1.09729	valid_1's rmse: 1.07082
# [25]	training's rmse: 1.09371	valid_1's rmse: 1.06831
# [26]	training's rmse: 1.09063	valid_1's rmse: 1.06595
# [27]	training's rmse: 1.08688	valid_1's rmse: 1.06301
# [28]	training's rmse: 1.08387	valid_1's rmse: 1.06091
# [29]	training's rmse: 1.0805	valid_1's rmse: 1.0586
# [30]	training's rmse: 1.07733	valid_1's rmse: 1.05638
# [31]	training's rmse: 1.07411	valid_1's rmse: 1.05423
# [32]	training's rmse: 1.07086	valid_1's rmse: 1.05204
# [33]	training's rmse: 1.0677	valid_1's rmse: 1.04981
# [34]	training's rmse: 1.06445	valid_1's rmse: 1.04758
# [35]	training's rmse: 1.06121	valid_1's rmse: 1.04522
# [36]	training's rmse: 1.05848	valid_1's rmse: 1.04332
# [37]	training's rmse: 1.05502	valid_1's rmse: 1.04067
# [38]	training's rmse: 1.05235	valid_1's rmse: 1.03885
# [39]	training's rmse: 1.04932	valid_1's rmse: 1.0367
# [40]	training's rmse: 1.04609	valid_1's rmse: 1.03428
# [41]	training's rmse: 1.04319	valid_1's rmse: 1.03238
# [42]	training's rmse: 1.04113	valid_1's rmse: 1.03103
# [43]	training's rmse: 1.03851	valid_1's rmse: 1.02908
# [44]	training's rmse: 1.03579	valid_1's rmse: 1.0273
# [45]	training's rmse: 1.03302	valid_1's rmse: 1.02551
# [46]	training's rmse: 1.03043	valid_1's rmse: 1.02375
# [47]	training's rmse: 1.0275	valid_1's rmse: 1.02179
# [48]	training's rmse: 1.02561	valid_1's rmse: 1.02
# [49]	training's rmse: 1.02283	valid_1's rmse: 1.01802
# [50]	training's rmse: 1.02067	valid_1's rmse: 1.01645
# [51]	training's rmse: 1.01821	valid_1's rmse: 1.01446
# [52]	training's rmse: 1.01548	valid_1's rmse: 1.01241
# [53]	training's rmse: 1.01326	valid_1's rmse: 1.011
# [54]	training's rmse: 1.01148	valid_1's rmse: 1.00983
# [55]	training's rmse: 1.00935	valid_1's rmse: 1.00831
# [56]	training's rmse: 1.00657	valid_1's rmse: 1.00633
# [57]	training's rmse: 1.00433	valid_1's rmse: 1.00499
# [58]	training's rmse: 1.00205	valid_1's rmse: 1.00358
# [59]	training's rmse: 1.0003	valid_1's rmse: 1.00225
# [60]	training's rmse: 0.997896	valid_1's rmse: 1.00068
# [61]	training's rmse: 0.995471	valid_1's rmse: 0.998943
# [62]	training's rmse: 0.993825	valid_1's rmse: 0.997826
# [63]	training's rmse: 0.991752	valid_1's rmse: 0.996539
# [64]	training's rmse: 0.989618	valid_1's rmse: 0.99522
# [65]	training's rmse: 0.987629	valid_1's rmse: 0.993861
# [66]	training's rmse: 0.985505	valid_1's rmse: 0.99238
# [67]	training's rmse: 0.983147	valid_1's rmse: 0.990619
# [68]	training's rmse: 0.980883	valid_1's rmse: 0.989095
# [69]	training's rmse: 0.978782	valid_1's rmse: 0.987859
# [70]	training's rmse: 0.977359	valid_1's rmse: 0.986943
# [71]	training's rmse: 0.975847	valid_1's rmse: 0.985962
# [72]	training's rmse: 0.97388	valid_1's rmse: 0.9846
# [73]	training's rmse: 0.971937	valid_1's rmse: 0.983447
# [74]	training's rmse: 0.970037	valid_1's rmse: 0.982264
# [75]	training's rmse: 0.968365	valid_1's rmse: 0.981219
# [76]	training's rmse: 0.967091	valid_1's rmse: 0.980388
# [77]	training's rmse: 0.965755	valid_1's rmse: 0.979416
# [78]	training's rmse: 0.963949	valid_1's rmse: 0.978206
# [79]	training's rmse: 0.962575	valid_1's rmse: 0.977215
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	training's rmse: 0.961658	valid_1's rmse: 0.976366
# [81]	training's rmse: 0.959986	valid_1's rmse: 0.975344
# [82]	training's rmse: 0.958406	valid_1's rmse: 0.974351
# [83]	training's rmse: 0.956818	valid_1's rmse: 0.973364
# [84]	training's rmse: 0.955284	valid_1's rmse: 0.972428
# [85]	training's rmse: 0.953771	valid_1's rmse: 0.971545
# [86]	training's rmse: 0.951848	valid_1's rmse: 0.970228
# [87]	training's rmse: 0.950207	valid_1's rmse: 0.969299
# [88]	training's rmse: 0.948663	valid_1's rmse: 0.968334
# [89]	training's rmse: 0.947136	valid_1's rmse: 0.967474
# [90]	training's rmse: 0.945773	valid_1's rmse: 0.966479
# [91]	training's rmse: 0.944687	valid_1's rmse: 0.965816
# [92]	training's rmse: 0.943257	valid_1's rmse: 0.964965
# [93]	training's rmse: 0.941944	valid_1's rmse: 0.964194
# [94]	training's rmse: 0.940556	valid_1's rmse: 0.963354
# [95]	training's rmse: 0.939083	valid_1's rmse: 0.962527
# [96]	training's rmse: 0.937548	valid_1's rmse: 0.961517
# [97]	training's rmse: 0.936735	valid_1's rmse: 0.960978
# [98]	training's rmse: 0.935452	valid_1's rmse: 0.960237
# [99]	training's rmse: 0.933678	valid_1's rmse: 0.95908
# [100]	training's rmse: 0.93217	valid_1's rmse: 0.958226
# [101]	training's rmse: 0.930851	valid_1's rmse: 0.957491
# [102]	training's rmse: 0.929575	valid_1's rmse: 0.956753
# [103]	training's rmse: 0.92831	valid_1's rmse: 0.956051
# [104]	training's rmse: 0.927059	valid_1's rmse: 0.955169
# [105]	training's rmse: 0.925856	valid_1's rmse: 0.95434
# [106]	training's rmse: 0.924648	valid_1's rmse: 0.953696
# [107]	training's rmse: 0.923429	valid_1's rmse: 0.953013
# [108]	training's rmse: 0.922196	valid_1's rmse: 0.952316
# [109]	training's rmse: 0.921334	valid_1's rmse: 0.951658
# [110]	training's rmse: 0.920105	valid_1's rmse: 0.950977
# [111]	training's rmse: 0.918727	valid_1's rmse: 0.950112
# [112]	training's rmse: 0.917819	valid_1's rmse: 0.949691
# [113]	training's rmse: 0.916634	valid_1's rmse: 0.948756
# [114]	training's rmse: 0.915531	valid_1's rmse: 0.948154
# [115]	training's rmse: 0.914387	valid_1's rmse: 0.947536
# [116]	training's rmse: 0.913269	valid_1's rmse: 0.946903
# [117]	training's rmse: 0.91214	valid_1's rmse: 0.946244
# [118]	training's rmse: 0.911089	valid_1's rmse: 0.945689
# [119]	training's rmse: 0.910278	valid_1's rmse: 0.945182
# [120]	training's rmse: 0.909292	valid_1's rmse: 0.944504
# [121]	training's rmse: 0.908703	valid_1's rmse: 0.944149
# [122]	training's rmse: 0.907635	valid_1's rmse: 0.943519
# [123]	training's rmse: 0.906698	valid_1's rmse: 0.943068
# [124]	training's rmse: 0.906118	valid_1's rmse: 0.942719
# [125]	training's rmse: 0.904947	valid_1's rmse: 0.941884
# [126]	training's rmse: 0.90381	valid_1's rmse: 0.941195
# [127]	training's rmse: 0.903236	valid_1's rmse: 0.94081
# [128]	training's rmse: 0.902219	valid_1's rmse: 0.940278
# [129]	training's rmse: 0.901378	valid_1's rmse: 0.939873
# [130]	training's rmse: 0.900527	valid_1's rmse: 0.939376
# [131]	training's rmse: 0.899654	valid_1's rmse: 0.93872
# [132]	training's rmse: 0.898943	valid_1's rmse: 0.938362
# [133]	training's rmse: 0.898064	valid_1's rmse: 0.937876
# [134]	training's rmse: 0.897228	valid_1's rmse: 0.93742
# [135]	training's rmse: 0.896327	valid_1's rmse: 0.936986
# [136]	training's rmse: 0.895785	valid_1's rmse: 0.936646
# [137]	training's rmse: 0.894918	valid_1's rmse: 0.936108
# [138]	training's rmse: 0.894445	valid_1's rmse: 0.935813
# [139]	training's rmse: 0.893506	valid_1's rmse: 0.935336
# [140]	training's rmse: 0.892733	valid_1's rmse: 0.934967
# [141]	training's rmse: 0.892218	valid_1's rmse: 0.934689
# [142]	training's rmse: 0.891553	valid_1's rmse: 0.934405
# [143]	training's rmse: 0.890871	valid_1's rmse: 0.934083
# [144]	training's rmse: 0.890077	valid_1's rmse: 0.933788
# [145]	training's rmse: 0.889589	valid_1's rmse: 0.933517
# [146]	training's rmse: 0.888655	valid_1's rmse: 0.93287
# [147]	training's rmse: 0.888041	valid_1's rmse: 0.932573
# [148]	training's rmse: 0.88726	valid_1's rmse: 0.932187
# [149]	training's rmse: 0.886432	valid_1's rmse: 0.931708
# [150]	training's rmse: 0.885453	valid_1's rmse: 0.931134
# [151]	training's rmse: 0.884945	valid_1's rmse: 0.930857
# [152]	training's rmse: 0.884234	valid_1's rmse: 0.930515
# [153]	training's rmse: 0.883776	valid_1's rmse: 0.930219
# [154]	training's rmse: 0.882949	valid_1's rmse: 0.929657
# [155]	training's rmse: 0.882056	valid_1's rmse: 0.929158
# [156]	training's rmse: 0.881302	valid_1's rmse: 0.928772
# [157]	training's rmse: 0.880793	valid_1's rmse: 0.928433
# [158]	training's rmse: 0.880079	valid_1's rmse: 0.928028
# [159]	training's rmse: 0.879434	valid_1's rmse: 0.927753
# [160]	training's rmse: 0.878648	valid_1's rmse: 0.927319
# [161]	training's rmse: 0.87786	valid_1's rmse: 0.926831
# [162]	training's rmse: 0.87709	valid_1's rmse: 0.926252
# [163]	training's rmse: 0.876712	valid_1's rmse: 0.926034
# [164]	training's rmse: 0.876072	valid_1's rmse: 0.925692
# [165]	training's rmse: 0.875475	valid_1's rmse: 0.925458
# [166]	training's rmse: 0.874982	valid_1's rmse: 0.925259
# [167]	training's rmse: 0.874403	valid_1's rmse: 0.924989
# [168]	training's rmse: 0.873698	valid_1's rmse: 0.924671
# [169]	training's rmse: 0.872965	valid_1's rmse: 0.924263
# [170]	training's rmse: 0.872452	valid_1's rmse: 0.924045
# [171]	training's rmse: 0.871882	valid_1's rmse: 0.923772
# [172]	training's rmse: 0.871158	valid_1's rmse: 0.923295
# [173]	training's rmse: 0.8706	valid_1's rmse: 0.923077
# [174]	training's rmse: 0.870009	valid_1's rmse: 0.922761
# [175]	training's rmse: 0.869542	valid_1's rmse: 0.922569
# [176]	training's rmse: 0.868996	valid_1's rmse: 0.922346
# [177]	training's rmse: 0.868344	valid_1's rmse: 0.922058
# [178]	training's rmse: 0.867938	valid_1's rmse: 0.921817
# [179]	training's rmse: 0.867383	valid_1's rmse: 0.92149
# [180]	training's rmse: 0.866745	valid_1's rmse: 0.921174
# [181]	training's rmse: 0.866262	valid_1's rmse: 0.921012
# [182]	training's rmse: 0.865825	valid_1's rmse: 0.920749
# [183]	training's rmse: 0.86517	valid_1's rmse: 0.920364
# [184]	training's rmse: 0.864748	valid_1's rmse: 0.920214
# [185]	training's rmse: 0.864206	valid_1's rmse: 0.919904
# [186]	training's rmse: 0.863784	valid_1's rmse: 0.919739
# [187]	training's rmse: 0.863311	valid_1's rmse: 0.919523
# [188]	training's rmse: 0.862947	valid_1's rmse: 0.919398
# [189]	training's rmse: 0.862519	valid_1's rmse: 0.919252
# [190]	training's rmse: 0.862116	valid_1's rmse: 0.919087
# [191]	training's rmse: 0.861498	valid_1's rmse: 0.91877
# [192]	training's rmse: 0.861114	valid_1's rmse: 0.918641
# [193]	training's rmse: 0.860642	valid_1's rmse: 0.918447
# [194]	training's rmse: 0.860223	valid_1's rmse: 0.918277
# [195]	training's rmse: 0.859749	valid_1's rmse: 0.918055
# [196]	training's rmse: 0.85954	valid_1's rmse: 0.917995
# [197]	training's rmse: 0.859099	valid_1's rmse: 0.9178
# [198]	training's rmse: 0.858661	valid_1's rmse: 0.917689
# [199]	training's rmse: 0.858322	valid_1's rmse: 0.917572
# [200]	training's rmse: 0.857692	valid_1's rmse: 0.917171
# [201]	training's rmse: 0.857335	valid_1's rmse: 0.917022
# [202]	training's rmse: 0.85685	valid_1's rmse: 0.916824
# [203]	training's rmse: 0.856581	valid_1's rmse: 0.916718
# [204]	training's rmse: 0.856207	valid_1's rmse: 0.916592
# [205]	training's rmse: 0.855832	valid_1's rmse: 0.916408
# [206]	training's rmse: 0.855525	valid_1's rmse: 0.916311
# [207]	training's rmse: 0.855174	valid_1's rmse: 0.916063
# [208]	training's rmse: 0.854653	valid_1's rmse: 0.915828
# [209]	training's rmse: 0.854182	valid_1's rmse: 0.915555
# [210]	training's rmse: 0.853644	valid_1's rmse: 0.915309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [211]	training's rmse: 0.853332	valid_1's rmse: 0.915139
# [212]	training's rmse: 0.852952	valid_1's rmse: 0.914893
# [213]	training's rmse: 0.852313	valid_1's rmse: 0.914578
# [214]	training's rmse: 0.851928	valid_1's rmse: 0.914455
# [215]	training's rmse: 0.851493	valid_1's rmse: 0.914378
# [216]	training's rmse: 0.851129	valid_1's rmse: 0.914243
# [217]	training's rmse: 0.850753	valid_1's rmse: 0.914053
# [218]	training's rmse: 0.850218	valid_1's rmse: 0.913896
# [219]	training's rmse: 0.850061	valid_1's rmse: 0.91381
# [220]	training's rmse: 0.849683	valid_1's rmse: 0.913652
# [221]	training's rmse: 0.849392	valid_1's rmse: 0.913592
# [222]	training's rmse: 0.848854	valid_1's rmse: 0.913191
# [223]	training's rmse: 0.848553	valid_1's rmse: 0.913095
# [224]	training's rmse: 0.848167	valid_1's rmse: 0.912992
# [225]	training's rmse: 0.847753	valid_1's rmse: 0.91283
# [226]	training's rmse: 0.847474	valid_1's rmse: 0.912775
# [227]	training's rmse: 0.847153	valid_1's rmse: 0.912508
# [228]	training's rmse: 0.846916	valid_1's rmse: 0.912457
# [229]	training's rmse: 0.846587	valid_1's rmse: 0.912381
# [230]	training's rmse: 0.846368	valid_1's rmse: 0.912293
# [231]	training's rmse: 0.84608	valid_1's rmse: 0.912235
# [232]	training's rmse: 0.845794	valid_1's rmse: 0.91214
# [233]	training's rmse: 0.845558	valid_1's rmse: 0.912083
# [234]	training's rmse: 0.84533	valid_1's rmse: 0.912028
# [235]	training's rmse: 0.844901	valid_1's rmse: 0.911954
# [236]	training's rmse: 0.844643	valid_1's rmse: 0.911889
# [237]	training's rmse: 0.844418	valid_1's rmse: 0.911878
# [238]	training's rmse: 0.844287	valid_1's rmse: 0.911797
# [239]	training's rmse: 0.843945	valid_1's rmse: 0.911721
# [240]	training's rmse: 0.843694	valid_1's rmse: 0.911684
# [241]	training's rmse: 0.843436	valid_1's rmse: 0.911603
# [242]	training's rmse: 0.843203	valid_1's rmse: 0.911464
# [243]	training's rmse: 0.842758	valid_1's rmse: 0.91121
# [244]	training's rmse: 0.842404	valid_1's rmse: 0.910967
# [245]	training's rmse: 0.842059	valid_1's rmse: 0.910758
# [246]	training's rmse: 0.841843	valid_1's rmse: 0.910687
# [247]	training's rmse: 0.841537	valid_1's rmse: 0.910531
# [248]	training's rmse: 0.841159	valid_1's rmse: 0.910328
# [249]	training's rmse: 0.840935	valid_1's rmse: 0.910216
# [250]	training's rmse: 0.840687	valid_1's rmse: 0.910201
# [251]	training's rmse: 0.840366	valid_1's rmse: 0.910156
# [252]	training's rmse: 0.840121	valid_1's rmse: 0.910071
# [253]	training's rmse: 0.839875	valid_1's rmse: 0.910034
# [254]	training's rmse: 0.839685	valid_1's rmse: 0.90997
# [255]	training's rmse: 0.839531	valid_1's rmse: 0.90987
# [256]	training's rmse: 0.839292	valid_1's rmse: 0.909809
# [257]	training's rmse: 0.839087	valid_1's rmse: 0.909821
# [258]	training's rmse: 0.838913	valid_1's rmse: 0.909811
# [259]	training's rmse: 0.838653	valid_1's rmse: 0.909763
# [260]	training's rmse: 0.838422	valid_1's rmse: 0.909678
# [261]	training's rmse: 0.838218	valid_1's rmse: 0.90959
# [262]	training's rmse: 0.837882	valid_1's rmse: 0.909469
# [263]	training's rmse: 0.837692	valid_1's rmse: 0.909432
# [264]	training's rmse: 0.837515	valid_1's rmse: 0.909432
# [265]	training's rmse: 0.837175	valid_1's rmse: 0.909323
# [266]	training's rmse: 0.836943	valid_1's rmse: 0.909199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	training's rmse: 0.836772	valid_1's rmse: 0.909186
# [268]	training's rmse: 0.836518	valid_1's rmse: 0.90912
# [269]	training's rmse: 0.836181	valid_1's rmse: 0.909023
# [270]	training's rmse: 0.835975	valid_1's rmse: 0.909
# [271]	training's rmse: 0.835794	valid_1's rmse: 0.90898
# [272]	training's rmse: 0.835653	valid_1's rmse: 0.908946
# [273]	training's rmse: 0.835431	valid_1's rmse: 0.908907
# [274]	training's rmse: 0.835156	valid_1's rmse: 0.908801
# [275]	training's rmse: 0.834943	valid_1's rmse: 0.908776
# [276]	training's rmse: 0.834756	valid_1's rmse: 0.908648
# [277]	training's rmse: 0.834516	valid_1's rmse: 0.908556
# [278]	training's rmse: 0.834328	valid_1's rmse: 0.908449
# [279]	training's rmse: 0.834069	valid_1's rmse: 0.908388
# [280]	training's rmse: 0.833711	valid_1's rmse: 0.908226
# [281]	training's rmse: 0.833467	valid_1's rmse: 0.908161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	training's rmse: 0.833263	valid_1's rmse: 0.908128
# [283]	training's rmse: 0.833029	valid_1's rmse: 0.908049
# [284]	training's rmse: 0.832921	valid_1's rmse: 0.907976
# [285]	training's rmse: 0.83271	valid_1's rmse: 0.907944
# [286]	training's rmse: 0.832541	valid_1's rmse: 0.90789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	training's rmse: 0.832362	valid_1's rmse: 0.90786
# [288]	training's rmse: 0.832133	valid_1's rmse: 0.907804
# [289]	training's rmse: 0.831985	valid_1's rmse: 0.90773
# [290]	training's rmse: 0.831838	valid_1's rmse: 0.90771
# [291]	training's rmse: 0.831478	valid_1's rmse: 0.907594
# [292]	training's rmse: 0.831349	valid_1's rmse: 0.907557
# [293]	training's rmse: 0.831168	valid_1's rmse: 0.907562
# [294]	training's rmse: 0.830833	valid_1's rmse: 0.907468
# [295]	training's rmse: 0.830579	valid_1's rmse: 0.907415
# [296]	training's rmse: 0.830416	valid_1's rmse: 0.907408
# [297]	training's rmse: 0.830276	valid_1's rmse: 0.90742
# [298]	training's rmse: 0.830129	valid_1's rmse: 0.907405
# [299]	training's rmse: 0.829986	valid_1's rmse: 0.907355
# [300]	training's rmse: 0.829777	valid_1's rmse: 0.907302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	training's rmse: 0.829603	valid_1's rmse: 0.90725
# [302]	training's rmse: 0.829319	valid_1's rmse: 0.907144
# [303]	training's rmse: 0.829225	valid_1's rmse: 0.907099
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	training's rmse: 0.828952	valid_1's rmse: 0.907037
# [305]	training's rmse: 0.828865	valid_1's rmse: 0.907011
# [306]	training's rmse: 0.828767	valid_1's rmse: 0.90699
# [307]	training's rmse: 0.828378	valid_1's rmse: 0.906795
# [308]	training's rmse: 0.828125	valid_1's rmse: 0.906689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [309]	training's rmse: 0.827961	valid_1's rmse: 0.90663
# [310]	training's rmse: 0.827793	valid_1's rmse: 0.906608
# [311]	training's rmse: 0.827668	valid_1's rmse: 0.906573
# [312]	training's rmse: 0.827476	valid_1's rmse: 0.906541
# [313]	training's rmse: 0.827272	valid_1's rmse: 0.906457
# [314]	training's rmse: 0.827052	valid_1's rmse: 0.906491
# [315]	training's rmse: 0.826802	valid_1's rmse: 0.906384
# [316]	training's rmse: 0.826654	valid_1's rmse: 0.906399
# [317]	training's rmse: 0.826432	valid_1's rmse: 0.906366
# [318]	training's rmse: 0.826157	valid_1's rmse: 0.906388
# [319]	training's rmse: 0.825961	valid_1's rmse: 0.906409
# [320]	training's rmse: 0.825778	valid_1's rmse: 0.906392
# [321]	training's rmse: 0.825687	valid_1's rmse: 0.906366
# [322]	training's rmse: 0.825448	valid_1's rmse: 0.906224
# [323]	training's rmse: 0.825239	valid_1's rmse: 0.906158
# [324]	training's rmse: 0.825127	valid_1's rmse: 0.906193
# [325]	training's rmse: 0.824982	valid_1's rmse: 0.906172
# [326]	training's rmse: 0.824872	valid_1's rmse: 0.906171
# [327]	training's rmse: 0.824505	valid_1's rmse: 0.905989
# [328]	training's rmse: 0.82435	valid_1's rmse: 0.906002
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [329]	training's rmse: 0.824194	valid_1's rmse: 0.90598
# [330]	training's rmse: 0.824042	valid_1's rmse: 0.905961
# [331]	training's rmse: 0.823828	valid_1's rmse: 0.905951
# [332]	training's rmse: 0.823704	valid_1's rmse: 0.905923
# [333]	training's rmse: 0.823571	valid_1's rmse: 0.90592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	training's rmse: 0.823407	valid_1's rmse: 0.905909
# [335]	training's rmse: 0.823198	valid_1's rmse: 0.905811
# [336]	training's rmse: 0.82297	valid_1's rmse: 0.905695
# [337]	training's rmse: 0.822784	valid_1's rmse: 0.905758
# [338]	training's rmse: 0.822632	valid_1's rmse: 0.905754
# [339]	training's rmse: 0.822398	valid_1's rmse: 0.905607
# [340]	training's rmse: 0.822235	valid_1's rmse: 0.905429
# [341]	training's rmse: 0.822082	valid_1's rmse: 0.905415
# [342]	training's rmse: 0.821919	valid_1's rmse: 0.905428
# [343]	training's rmse: 0.821786	valid_1's rmse: 0.905414
# [344]	training's rmse: 0.821709	valid_1's rmse: 0.905386
# [345]	training's rmse: 0.821464	valid_1's rmse: 0.905333
# [346]	training's rmse: 0.821376	valid_1's rmse: 0.905311
# [347]	training's rmse: 0.821254	valid_1's rmse: 0.905318
# [348]	training's rmse: 0.821058	valid_1's rmse: 0.905265
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [349]	training's rmse: 0.820887	valid_1's rmse: 0.905253
# [350]	training's rmse: 0.820666	valid_1's rmse: 0.905157
# [351]	training's rmse: 0.820501	valid_1's rmse: 0.90513
# [352]	training's rmse: 0.82039	valid_1's rmse: 0.905141
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	training's rmse: 0.820261	valid_1's rmse: 0.905087
# [354]	training's rmse: 0.820144	valid_1's rmse: 0.905063
# [355]	training's rmse: 0.819999	valid_1's rmse: 0.905036
# [356]	training's rmse: 0.819827	valid_1's rmse: 0.905037
# [357]	training's rmse: 0.819692	valid_1's rmse: 0.905009
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [358]	training's rmse: 0.819641	valid_1's rmse: 0.905
# [359]	training's rmse: 0.819527	valid_1's rmse: 0.904999
# [360]	training's rmse: 0.819378	valid_1's rmse: 0.904992
# [361]	training's rmse: 0.819302	valid_1's rmse: 0.904992
# [362]	training's rmse: 0.819218	valid_1's rmse: 0.90498
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [363]	training's rmse: 0.81908	valid_1's rmse: 0.904948
# [364]	training's rmse: 0.81889	valid_1's rmse: 0.9049
# [365]	training's rmse: 0.818764	valid_1's rmse: 0.904893
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [366]	training's rmse: 0.818607	valid_1's rmse: 0.904845
# [367]	training's rmse: 0.818383	valid_1's rmse: 0.904733
# [368]	training's rmse: 0.818314	valid_1's rmse: 0.904728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	training's rmse: 0.818218	valid_1's rmse: 0.904759
# [370]	training's rmse: 0.818079	valid_1's rmse: 0.904738
# [371]	training's rmse: 0.817973	valid_1's rmse: 0.904758
# [372]	training's rmse: 0.817703	valid_1's rmse: 0.904885
# [373]	training's rmse: 0.817631	valid_1's rmse: 0.904852
# [374]	training's rmse: 0.817499	valid_1's rmse: 0.904862
# [375]	training's rmse: 0.817354	valid_1's rmse: 0.904839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	training's rmse: 0.817228	valid_1's rmse: 0.904841
# [377]	training's rmse: 0.817145	valid_1's rmse: 0.90486
# [378]	training's rmse: 0.81708	valid_1's rmse: 0.904842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	training's rmse: 0.81699	valid_1's rmse: 0.904877
# [380]	training's rmse: 0.816834	valid_1's rmse: 0.904889
# [381]	training's rmse: 0.816725	valid_1's rmse: 0.904841
# [382]	training's rmse: 0.816457	valid_1's rmse: 0.90461
# [383]	training's rmse: 0.816315	valid_1's rmse: 0.904579
# [384]	training's rmse: 0.816182	valid_1's rmse: 0.904537
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	training's rmse: 0.816016	valid_1's rmse: 0.904495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	training's rmse: 0.815918	valid_1's rmse: 0.904521
# [387]	training's rmse: 0.815854	valid_1's rmse: 0.904504
# [388]	training's rmse: 0.815622	valid_1's rmse: 0.904468
# [389]	training's rmse: 0.815482	valid_1's rmse: 0.904493
# [390]	training's rmse: 0.815163	valid_1's rmse: 0.904398
# [391]	training's rmse: 0.815054	valid_1's rmse: 0.904376
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	training's rmse: 0.814991	valid_1's rmse: 0.90437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	training's rmse: 0.814891	valid_1's rmse: 0.904305
# [394]	training's rmse: 0.814811	valid_1's rmse: 0.904297
# [395]	training's rmse: 0.814694	valid_1's rmse: 0.904289
# [396]	training's rmse: 0.814529	valid_1's rmse: 0.904286
# [397]	training's rmse: 0.814274	valid_1's rmse: 0.90444
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	training's rmse: 0.814112	valid_1's rmse: 0.904441
# [399]	training's rmse: 0.813967	valid_1's rmse: 0.904449
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	training's rmse: 0.813882	valid_1's rmse: 0.904441
# [401]	training's rmse: 0.813749	valid_1's rmse: 0.904433
# [402]	training's rmse: 0.813622	valid_1's rmse: 0.90441
# [403]	training's rmse: 0.813476	valid_1's rmse: 0.904386
# [404]	training's rmse: 0.813386	valid_1's rmse: 0.904361
# [405]	training's rmse: 0.813294	valid_1's rmse: 0.9044
# [406]	training's rmse: 0.813156	valid_1's rmse: 0.904442
# [407]	training's rmse: 0.813094	valid_1's rmse: 0.904439
# [408]	training's rmse: 0.812947	valid_1's rmse: 0.904437
# [409]	training's rmse: 0.812849	valid_1's rmse: 0.904389
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [410]	training's rmse: 0.81275	valid_1's rmse: 0.904452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [411]	training's rmse: 0.812602	valid_1's rmse: 0.904462
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [412]	training's rmse: 0.812516	valid_1's rmse: 0.904485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [413]	training's rmse: 0.812391	valid_1's rmse: 0.904503
# [414]	training's rmse: 0.812239	valid_1's rmse: 0.904453
# [415]	training's rmse: 0.812109	valid_1's rmse: 0.904341
# [416]	training's rmse: 0.812011	valid_1's rmse: 0.904353
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [417]	training's rmse: 0.811898	valid_1's rmse: 0.90432
# [418]	training's rmse: 0.811835	valid_1's rmse: 0.90431
# [419]	training's rmse: 0.811702	valid_1's rmse: 0.904305
# [420]	training's rmse: 0.811562	valid_1's rmse: 0.904237
# [421]	training's rmse: 0.811513	valid_1's rmse: 0.90423
# [422]	training's rmse: 0.811453	valid_1's rmse: 0.904209
# [423]	training's rmse: 0.811331	valid_1's rmse: 0.904185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [424]	training's rmse: 0.811239	valid_1's rmse: 0.904151
# [425]	training's rmse: 0.810909	valid_1's rmse: 0.904318
# [426]	training's rmse: 0.810746	valid_1's rmse: 0.904287
# [427]	training's rmse: 0.810637	valid_1's rmse: 0.904345
# [428]	training's rmse: 0.810427	valid_1's rmse: 0.904283
# [429]	training's rmse: 0.810281	valid_1's rmse: 0.904273
# [430]	training's rmse: 0.810131	valid_1's rmse: 0.904222
# [431]	training's rmse: 0.809998	valid_1's rmse: 0.904202
# [432]	training's rmse: 0.809925	valid_1's rmse: 0.90418
# [433]	training's rmse: 0.80984	valid_1's rmse: 0.904182
# [434]	training's rmse: 0.809726	valid_1's rmse: 0.904176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [435]	training's rmse: 0.80965	valid_1's rmse: 0.90418
# [436]	training's rmse: 0.809588	valid_1's rmse: 0.904179
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [437]	training's rmse: 0.809529	valid_1's rmse: 0.904166
# [438]	training's rmse: 0.80944	valid_1's rmse: 0.904164
# [439]	training's rmse: 0.809369	valid_1's rmse: 0.904151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [440]	training's rmse: 0.809291	valid_1's rmse: 0.904135
# [441]	training's rmse: 0.809223	valid_1's rmse: 0.904127
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [442]	training's rmse: 0.809148	valid_1's rmse: 0.904134
# [443]	training's rmse: 0.808932	valid_1's rmse: 0.904026
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [444]	training's rmse: 0.808849	valid_1's rmse: 0.904056
# [445]	training's rmse: 0.808741	valid_1's rmse: 0.90408
# [446]	training's rmse: 0.808627	valid_1's rmse: 0.904067
# [447]	training's rmse: 0.80836	valid_1's rmse: 0.904221
# [448]	training's rmse: 0.808285	valid_1's rmse: 0.904193
# [449]	training's rmse: 0.808174	valid_1's rmse: 0.904201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	training's rmse: 0.808103	valid_1's rmse: 0.904207
# [451]	training's rmse: 0.807991	valid_1's rmse: 0.90417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [452]	training's rmse: 0.807919	valid_1's rmse: 0.904175
# [453]	training's rmse: 0.807853	valid_1's rmse: 0.904136
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [454]	training's rmse: 0.807753	valid_1's rmse: 0.904196
# [455]	training's rmse: 0.807622	valid_1's rmse: 0.904233
# [456]	training's rmse: 0.807549	valid_1's rmse: 0.904239
# [457]	training's rmse: 0.80736	valid_1's rmse: 0.904129
# [458]	training's rmse: 0.807248	valid_1's rmse: 0.904109
# [459]	training's rmse: 0.807164	valid_1's rmse: 0.904111
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [460]	training's rmse: 0.807082	valid_1's rmse: 0.904105
# [461]	training's rmse: 0.807025	valid_1's rmse: 0.904067
# [462]	training's rmse: 0.806901	valid_1's rmse: 0.904063
# [463]	training's rmse: 0.806821	valid_1's rmse: 0.90405
# [464]	training's rmse: 0.80673	valid_1's rmse: 0.903996
# [465]	training's rmse: 0.806642	valid_1's rmse: 0.903972
# [466]	training's rmse: 0.806501	valid_1's rmse: 0.90402
# [467]	training's rmse: 0.806409	valid_1's rmse: 0.903949
# [468]	training's rmse: 0.80632	valid_1's rmse: 0.903906
# [469]	training's rmse: 0.806219	valid_1's rmse: 0.903885
# [470]	training's rmse: 0.806116	valid_1's rmse: 0.90387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [471]	training's rmse: 0.806048	valid_1's rmse: 0.903791
# [472]	training's rmse: 0.805891	valid_1's rmse: 0.903771
# [473]	training's rmse: 0.805843	valid_1's rmse: 0.903762
# [474]	training's rmse: 0.805788	valid_1's rmse: 0.903757
# [475]	training's rmse: 0.805733	valid_1's rmse: 0.903755
# [476]	training's rmse: 0.805636	valid_1's rmse: 0.903765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [477]	training's rmse: 0.805558	valid_1's rmse: 0.903735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [478]	training's rmse: 0.805515	valid_1's rmse: 0.903722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [479]	training's rmse: 0.805451	valid_1's rmse: 0.903717
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [480]	training's rmse: 0.805408	valid_1's rmse: 0.903739
# [481]	training's rmse: 0.805276	valid_1's rmse: 0.903607
# [482]	training's rmse: 0.805211	valid_1's rmse: 0.903695
# [483]	training's rmse: 0.805087	valid_1's rmse: 0.903662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [484]	training's rmse: 0.804993	valid_1's rmse: 0.903643
# [485]	training's rmse: 0.804791	valid_1's rmse: 0.903592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [486]	training's rmse: 0.804726	valid_1's rmse: 0.903591
# [487]	training's rmse: 0.804672	valid_1's rmse: 0.903581
# [488]	training's rmse: 0.804489	valid_1's rmse: 0.90348
# [489]	training's rmse: 0.80435	valid_1's rmse: 0.903457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [490]	training's rmse: 0.804305	valid_1's rmse: 0.903433
# [491]	training's rmse: 0.804207	valid_1's rmse: 0.903421
# [492]	training's rmse: 0.803935	valid_1's rmse: 0.903687
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [493]	training's rmse: 0.80388	valid_1's rmse: 0.903707
# [494]	training's rmse: 0.803798	valid_1's rmse: 0.903693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [495]	training's rmse: 0.803737	valid_1's rmse: 0.903715
# [496]	training's rmse: 0.803689	valid_1's rmse: 0.903704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [497]	training's rmse: 0.803624	valid_1's rmse: 0.903704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [498]	training's rmse: 0.803581	valid_1's rmse: 0.903692
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [499]	training's rmse: 0.803521	valid_1's rmse: 0.903765
# [500]	training's rmse: 0.803448	valid_1's rmse: 0.903752
# [501]	training's rmse: 0.803254	valid_1's rmse: 0.90363
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [502]	training's rmse: 0.803162	valid_1's rmse: 0.903611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [503]	training's rmse: 0.803097	valid_1's rmse: 0.903535
# [504]	training's rmse: 0.803025	valid_1's rmse: 0.903522
# [505]	training's rmse: 0.802943	valid_1's rmse: 0.903511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [506]	training's rmse: 0.802887	valid_1's rmse: 0.903547
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [507]	training's rmse: 0.80281	valid_1's rmse: 0.903487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [508]	training's rmse: 0.802687	valid_1's rmse: 0.903455
# [509]	training's rmse: 0.802611	valid_1's rmse: 0.903432
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [510]	training's rmse: 0.802498	valid_1's rmse: 0.903452
# [511]	training's rmse: 0.80244	valid_1's rmse: 0.903442
# [512]	training's rmse: 0.802315	valid_1's rmse: 0.903433
# [513]	training's rmse: 0.802205	valid_1's rmse: 0.903429
# [514]	training's rmse: 0.802123	valid_1's rmse: 0.903443
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [515]	training's rmse: 0.802014	valid_1's rmse: 0.903458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [516]	training's rmse: 0.80192	valid_1's rmse: 0.903473
# [517]	training's rmse: 0.801827	valid_1's rmse: 0.903573
# [518]	training's rmse: 0.801726	valid_1's rmse: 0.90347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [519]	training's rmse: 0.801692	valid_1's rmse: 0.903467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [520]	training's rmse: 0.801652	valid_1's rmse: 0.903475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [521]	training's rmse: 0.801602	valid_1's rmse: 0.903484
# [522]	training's rmse: 0.801487	valid_1's rmse: 0.903448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [523]	training's rmse: 0.801427	valid_1's rmse: 0.903432
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [524]	training's rmse: 0.80138	valid_1's rmse: 0.903406
# [525]	training's rmse: 0.801281	valid_1's rmse: 0.903392
# [526]	training's rmse: 0.80113	valid_1's rmse: 0.903259
# [527]	training's rmse: 0.801014	valid_1's rmse: 0.903221
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [528]	training's rmse: 0.800947	valid_1's rmse: 0.903246
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [529]	training's rmse: 0.800879	valid_1's rmse: 0.903259
# [530]	training's rmse: 0.800735	valid_1's rmse: 0.903139
# [531]	training's rmse: 0.800646	valid_1's rmse: 0.90314
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [532]	training's rmse: 0.800573	valid_1's rmse: 0.903114
# [533]	training's rmse: 0.800473	valid_1's rmse: 0.903118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [534]	training's rmse: 0.800419	valid_1's rmse: 0.903134
# [535]	training's rmse: 0.800292	valid_1's rmse: 0.903142
# [536]	training's rmse: 0.800179	valid_1's rmse: 0.903155
# [537]	training's rmse: 0.800106	valid_1's rmse: 0.903141
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [538]	training's rmse: 0.800051	valid_1's rmse: 0.903115
# [539]	training's rmse: 0.799982	valid_1's rmse: 0.90314
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [540]	training's rmse: 0.799876	valid_1's rmse: 0.90307
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [541]	training's rmse: 0.799802	valid_1's rmse: 0.903095
# [542]	training's rmse: 0.7997	valid_1's rmse: 0.903087
# [543]	training's rmse: 0.79961	valid_1's rmse: 0.903123
# [544]	training's rmse: 0.799526	valid_1's rmse: 0.903147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [545]	training's rmse: 0.799476	valid_1's rmse: 0.903177
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [546]	training's rmse: 0.79942	valid_1's rmse: 0.903164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [547]	training's rmse: 0.799376	valid_1's rmse: 0.903154
# [548]	training's rmse: 0.799315	valid_1's rmse: 0.903212
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [549]	training's rmse: 0.799262	valid_1's rmse: 0.903242
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	training's rmse: 0.799195	valid_1's rmse: 0.903233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [551]	training's rmse: 0.799156	valid_1's rmse: 0.903218
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [552]	training's rmse: 0.799128	valid_1's rmse: 0.903209
# [553]	training's rmse: 0.799029	valid_1's rmse: 0.903169
# [554]	training's rmse: 0.798908	valid_1's rmse: 0.90299
# [555]	training's rmse: 0.798727	valid_1's rmse: 0.902967
# [556]	training's rmse: 0.79864	valid_1's rmse: 0.902907
# [557]	training's rmse: 0.798565	valid_1's rmse: 0.902925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [558]	training's rmse: 0.798496	valid_1's rmse: 0.902918
# [559]	training's rmse: 0.798444	valid_1's rmse: 0.9029
# [560]	training's rmse: 0.798401	valid_1's rmse: 0.902901
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [561]	training's rmse: 0.798337	valid_1's rmse: 0.902903
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [562]	training's rmse: 0.798308	valid_1's rmse: 0.902866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [563]	training's rmse: 0.798265	valid_1's rmse: 0.902889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [564]	training's rmse: 0.798236	valid_1's rmse: 0.902878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [565]	training's rmse: 0.798173	valid_1's rmse: 0.902885
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [566]	training's rmse: 0.798136	valid_1's rmse: 0.902875
# [567]	training's rmse: 0.79807	valid_1's rmse: 0.90295
# [568]	training's rmse: 0.798023	valid_1's rmse: 0.902946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [569]	training's rmse: 0.797982	valid_1's rmse: 0.902938
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [570]	training's rmse: 0.797924	valid_1's rmse: 0.903002
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [571]	training's rmse: 0.797826	valid_1's rmse: 0.902926
# [572]	training's rmse: 0.797742	valid_1's rmse: 0.902896
# [573]	training's rmse: 0.797657	valid_1's rmse: 0.902866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [574]	training's rmse: 0.797619	valid_1's rmse: 0.902854
# [575]	training's rmse: 0.797527	valid_1's rmse: 0.902838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [576]	training's rmse: 0.797488	valid_1's rmse: 0.902833
# [577]	training's rmse: 0.797093	valid_1's rmse: 0.903035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [578]	training's rmse: 0.797041	valid_1's rmse: 0.903053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [579]	training's rmse: 0.796949	valid_1's rmse: 0.903095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [580]	training's rmse: 0.796897	valid_1's rmse: 0.903085
# [581]	training's rmse: 0.796835	valid_1's rmse: 0.903041
# [582]	training's rmse: 0.796731	valid_1's rmse: 0.903051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [583]	training's rmse: 0.796673	valid_1's rmse: 0.903061
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [584]	training's rmse: 0.796626	valid_1's rmse: 0.90303
# [585]	training's rmse: 0.796509	valid_1's rmse: 0.903039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [586]	training's rmse: 0.796454	valid_1's rmse: 0.903013
# [587]	training's rmse: 0.796394	valid_1's rmse: 0.902995
# [588]	training's rmse: 0.796273	valid_1's rmse: 0.903007
# [589]	training's rmse: 0.79621	valid_1's rmse: 0.903002
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [590]	training's rmse: 0.796181	valid_1's rmse: 0.902984
# [591]	training's rmse: 0.796121	valid_1's rmse: 0.90303
# [592]	training's rmse: 0.796027	valid_1's rmse: 0.903046
# [593]	training's rmse: 0.795959	valid_1's rmse: 0.903055
# [594]	training's rmse: 0.795691	valid_1's rmse: 0.902886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [595]	training's rmse: 0.795615	valid_1's rmse: 0.902892
# [596]	training's rmse: 0.795554	valid_1's rmse: 0.902898
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [597]	training's rmse: 0.795498	valid_1's rmse: 0.902896
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [598]	training's rmse: 0.795465	valid_1's rmse: 0.902924
# [599]	training's rmse: 0.795281	valid_1's rmse: 0.902925
# [600]	training's rmse: 0.795216	valid_1's rmse: 0.902928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [601]	training's rmse: 0.795166	valid_1's rmse: 0.902952
# [602]	training's rmse: 0.795094	valid_1's rmse: 0.902942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [603]	training's rmse: 0.795053	valid_1's rmse: 0.902949
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [604]	training's rmse: 0.794998	valid_1's rmse: 0.90295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [605]	training's rmse: 0.794955	valid_1's rmse: 0.902946
# [606]	training's rmse: 0.794813	valid_1's rmse: 0.90292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [607]	training's rmse: 0.794762	valid_1's rmse: 0.90291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [608]	training's rmse: 0.79465	valid_1's rmse: 0.902906
# [609]	training's rmse: 0.794589	valid_1's rmse: 0.902957
# [610]	training's rmse: 0.794548	valid_1's rmse: 0.902968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [611]	training's rmse: 0.794494	valid_1's rmse: 0.902959
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [612]	training's rmse: 0.794457	valid_1's rmse: 0.902958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [613]	training's rmse: 0.7944	valid_1's rmse: 0.902961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [614]	training's rmse: 0.794352	valid_1's rmse: 0.902958
# [615]	training's rmse: 0.794111	valid_1's rmse: 0.902875
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [616]	training's rmse: 0.794082	valid_1's rmse: 0.902883
# [617]	training's rmse: 0.793928	valid_1's rmse: 0.902891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [618]	training's rmse: 0.793883	valid_1's rmse: 0.902908
# [619]	training's rmse: 0.793815	valid_1's rmse: 0.902936
# [620]	training's rmse: 0.793767	valid_1's rmse: 0.902909
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [621]	training's rmse: 0.793703	valid_1's rmse: 0.902965
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [622]	training's rmse: 0.793668	valid_1's rmse: 0.902962
# [623]	training's rmse: 0.793532	valid_1's rmse: 0.902861
# [624]	training's rmse: 0.793482	valid_1's rmse: 0.902858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [625]	training's rmse: 0.793398	valid_1's rmse: 0.902819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [626]	training's rmse: 0.793346	valid_1's rmse: 0.902859
# [627]	training's rmse: 0.793293	valid_1's rmse: 0.902856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [628]	training's rmse: 0.793245	valid_1's rmse: 0.902857
# [629]	training's rmse: 0.793175	valid_1's rmse: 0.902895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [630]	training's rmse: 0.793084	valid_1's rmse: 0.902924
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [631]	training's rmse: 0.793033	valid_1's rmse: 0.902969
# [632]	training's rmse: 0.792916	valid_1's rmse: 0.902918
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [633]	training's rmse: 0.792854	valid_1's rmse: 0.902963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [634]	training's rmse: 0.792754	valid_1's rmse: 0.902983
# [635]	training's rmse: 0.792679	valid_1's rmse: 0.90302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [636]	training's rmse: 0.792643	valid_1's rmse: 0.903017
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [637]	training's rmse: 0.792616	valid_1's rmse: 0.903011
# [638]	training's rmse: 0.792578	valid_1's rmse: 0.902998
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [639]	training's rmse: 0.792529	valid_1's rmse: 0.902976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [640]	training's rmse: 0.792484	valid_1's rmse: 0.902976
# [641]	training's rmse: 0.792382	valid_1's rmse: 0.902986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [642]	training's rmse: 0.792333	valid_1's rmse: 0.902996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [643]	training's rmse: 0.792213	valid_1's rmse: 0.902793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [644]	training's rmse: 0.792142	valid_1's rmse: 0.902771
# [645]	training's rmse: 0.79207	valid_1's rmse: 0.902784
# [646]	training's rmse: 0.792018	valid_1's rmse: 0.902807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [647]	training's rmse: 0.791977	valid_1's rmse: 0.902814
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [648]	training's rmse: 0.791935	valid_1's rmse: 0.902825
# [649]	training's rmse: 0.791873	valid_1's rmse: 0.902813
# [650]	training's rmse: 0.791816	valid_1's rmse: 0.902817
# [651]	training's rmse: 0.791746	valid_1's rmse: 0.902837
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [652]	training's rmse: 0.791705	valid_1's rmse: 0.902821
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [653]	training's rmse: 0.791635	valid_1's rmse: 0.902768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [654]	training's rmse: 0.791594	valid_1's rmse: 0.902792
# [655]	training's rmse: 0.791484	valid_1's rmse: 0.9028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [656]	training's rmse: 0.79145	valid_1's rmse: 0.902812
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [657]	training's rmse: 0.791406	valid_1's rmse: 0.902771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [658]	training's rmse: 0.791347	valid_1's rmse: 0.902739
# ...
# [847]	training's rmse: 0.780673	valid_1's rmse: 0.902685
# [848]	training's rmse: 0.780614	valid_1's rmse: 0.902678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [849]	training's rmse: 0.780583	valid_1's rmse: 0.902685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's rmse: 0.78054	valid_1's rmse: 0.902678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [851]	training's rmse: 0.780513	valid_1's rmse: 0.902672
# [852]	training's rmse: 0.780432	valid_1's rmse: 0.902683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [853]	training's rmse: 0.780405	valid_1's rmse: 0.90268
# [854]	training's rmse: 0.780353	valid_1's rmse: 0.90267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [855]	training's rmse: 0.78033	valid_1's rmse: 0.902675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [856]	training's rmse: 0.780305	valid_1's rmse: 0.90268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [857]	training's rmse: 0.780275	valid_1's rmse: 0.902655
# [858]	training's rmse: 0.780196	valid_1's rmse: 0.902656
# [859]	training's rmse: 0.780142	valid_1's rmse: 0.90265
# [860]	training's rmse: 0.780093	valid_1's rmse: 0.902626
# [861]	training's rmse: 0.780056	valid_1's rmse: 0.902629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [862]	training's rmse: 0.779991	valid_1's rmse: 0.902653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [863]	training's rmse: 0.779942	valid_1's rmse: 0.902586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [864]	training's rmse: 0.779914	valid_1's rmse: 0.902599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [865]	training's rmse: 0.779873	valid_1's rmse: 0.902592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [866]	training's rmse: 0.779854	valid_1's rmse: 0.902584
# [867]	training's rmse: 0.779823	valid_1's rmse: 0.902581
# [868]	training's rmse: 0.779775	valid_1's rmse: 0.902547
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [869]	training's rmse: 0.77975	valid_1's rmse: 0.902552
# [870]	training's rmse: 0.779708	valid_1's rmse: 0.902548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [871]	training's rmse: 0.77968	valid_1's rmse: 0.902537
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [872]	training's rmse: 0.779607	valid_1's rmse: 0.902561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [873]	training's rmse: 0.779573	valid_1's rmse: 0.902536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [874]	training's rmse: 0.779537	valid_1's rmse: 0.902527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [875]	training's rmse: 0.779421	valid_1's rmse: 0.902516
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [876]	training's rmse: 0.779341	valid_1's rmse: 0.902527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [877]	training's rmse: 0.779293	valid_1's rmse: 0.902514
# [878]	training's rmse: 0.779228	valid_1's rmse: 0.902525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [879]	training's rmse: 0.779194	valid_1's rmse: 0.902515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [880]	training's rmse: 0.779154	valid_1's rmse: 0.902504
# [881]	training's rmse: 0.779113	valid_1's rmse: 0.902492
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [882]	training's rmse: 0.779079	valid_1's rmse: 0.902496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [883]	training's rmse: 0.779032	valid_1's rmse: 0.902516
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [884]	training's rmse: 0.779002	valid_1's rmse: 0.902556
# [885]	training's rmse: 0.778974	valid_1's rmse: 0.902551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [886]	training's rmse: 0.77895	valid_1's rmse: 0.902554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [887]	training's rmse: 0.778925	valid_1's rmse: 0.902559
# [888]	training's rmse: 0.778882	valid_1's rmse: 0.902547
# [889]	training's rmse: 0.778842	valid_1's rmse: 0.902576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [890]	training's rmse: 0.778815	valid_1's rmse: 0.902571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [891]	training's rmse: 0.778742	valid_1's rmse: 0.90256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [892]	training's rmse: 0.778713	valid_1's rmse: 0.902557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [893]	training's rmse: 0.778684	valid_1's rmse: 0.902554
# [894]	training's rmse: 0.778631	valid_1's rmse: 0.902526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [895]	training's rmse: 0.778602	valid_1's rmse: 0.902515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [896]	training's rmse: 0.778558	valid_1's rmse: 0.90252
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [897]	training's rmse: 0.778529	valid_1's rmse: 0.902501
# [898]	training's rmse: 0.778486	valid_1's rmse: 0.902493
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [899]	training's rmse: 0.778467	valid_1's rmse: 0.902496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	training's rmse: 0.778452	valid_1's rmse: 0.902494
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [901]	training's rmse: 0.77842	valid_1's rmse: 0.902476
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [902]	training's rmse: 0.778362	valid_1's rmse: 0.902438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [903]	training's rmse: 0.778337	valid_1's rmse: 0.902453
# [904]	training's rmse: 0.778316	valid_1's rmse: 0.902441
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [905]	training's rmse: 0.778294	valid_1's rmse: 0.90244
# [906]	training's rmse: 0.778254	valid_1's rmse: 0.902456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [907]	training's rmse: 0.778228	valid_1's rmse: 0.902456
# [908]	training's rmse: 0.778172	valid_1's rmse: 0.902432
# [909]	training's rmse: 0.778131	valid_1's rmse: 0.902439
# [910]	training's rmse: 0.778095	valid_1's rmse: 0.902455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [911]	training's rmse: 0.778072	valid_1's rmse: 0.902458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [912]	training's rmse: 0.778038	valid_1's rmse: 0.902454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [913]	training's rmse: 0.777967	valid_1's rmse: 0.902418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [914]	training's rmse: 0.777939	valid_1's rmse: 0.902422
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [915]	training's rmse: 0.777913	valid_1's rmse: 0.902415
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [916]	training's rmse: 0.777869	valid_1's rmse: 0.902438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [917]	training's rmse: 0.777844	valid_1's rmse: 0.902436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [918]	training's rmse: 0.777813	valid_1's rmse: 0.902428
# [919]	training's rmse: 0.77776	valid_1's rmse: 0.902418
# [920]	training's rmse: 0.777716	valid_1's rmse: 0.902408
# [921]	training's rmse: 0.77766	valid_1's rmse: 0.90242
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [922]	training's rmse: 0.777635	valid_1's rmse: 0.902416
# [923]	training's rmse: 0.777562	valid_1's rmse: 0.902376
# [924]	training's rmse: 0.777511	valid_1's rmse: 0.902359
# [925]	training's rmse: 0.777441	valid_1's rmse: 0.902364
# [926]	training's rmse: 0.777407	valid_1's rmse: 0.902383
# [927]	training's rmse: 0.777377	valid_1's rmse: 0.902403
# [928]	training's rmse: 0.777342	valid_1's rmse: 0.902414
# [929]	training's rmse: 0.7773	valid_1's rmse: 0.902385
# [930]	training's rmse: 0.777156	valid_1's rmse: 0.902516
# [931]	training's rmse: 0.777118	valid_1's rmse: 0.902524
# [932]	training's rmse: 0.777063	valid_1's rmse: 0.902534
# [933]	training's rmse: 0.777018	valid_1's rmse: 0.90256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [934]	training's rmse: 0.776982	valid_1's rmse: 0.902557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [935]	training's rmse: 0.776933	valid_1's rmse: 0.902563
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [936]	training's rmse: 0.776896	valid_1's rmse: 0.90257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [937]	training's rmse: 0.776863	valid_1's rmse: 0.902569
# [938]	training's rmse: 0.776805	valid_1's rmse: 0.902577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [939]	training's rmse: 0.776764	valid_1's rmse: 0.902581
# [940]	training's rmse: 0.776703	valid_1's rmse: 0.902611
# [941]	training's rmse: 0.776632	valid_1's rmse: 0.902585
# [942]	training's rmse: 0.77657	valid_1's rmse: 0.902536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [943]	training's rmse: 0.776538	valid_1's rmse: 0.902519
# [944]	training's rmse: 0.776475	valid_1's rmse: 0.902531
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [945]	training's rmse: 0.776455	valid_1's rmse: 0.902529
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [946]	training's rmse: 0.776408	valid_1's rmse: 0.902499
# [947]	training's rmse: 0.776365	valid_1's rmse: 0.902525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [948]	training's rmse: 0.776322	valid_1's rmse: 0.902526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [949]	training's rmse: 0.776272	valid_1's rmse: 0.902512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	training's rmse: 0.776242	valid_1's rmse: 0.902515
# [951]	training's rmse: 0.776198	valid_1's rmse: 0.902539
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [952]	training's rmse: 0.776182	valid_1's rmse: 0.90254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [953]	training's rmse: 0.776156	valid_1's rmse: 0.902538
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [954]	training's rmse: 0.776102	valid_1's rmse: 0.902543
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [955]	training's rmse: 0.776084	valid_1's rmse: 0.902557
# [956]	training's rmse: 0.776021	valid_1's rmse: 0.902606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [957]	training's rmse: 0.775986	valid_1's rmse: 0.902604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [958]	training's rmse: 0.775941	valid_1's rmse: 0.902603
# [959]	training's rmse: 0.775917	valid_1's rmse: 0.902606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [960]	training's rmse: 0.775866	valid_1's rmse: 0.902611
# [961]	training's rmse: 0.775838	valid_1's rmse: 0.902635
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [962]	training's rmse: 0.775814	valid_1's rmse: 0.902633
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [963]	training's rmse: 0.775789	valid_1's rmse: 0.902621
# [964]	training's rmse: 0.775725	valid_1's rmse: 0.90264
# [965]	training's rmse: 0.775682	valid_1's rmse: 0.90262
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [966]	training's rmse: 0.775664	valid_1's rmse: 0.902611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [967]	training's rmse: 0.775646	valid_1's rmse: 0.902616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [968]	training's rmse: 0.775612	valid_1's rmse: 0.902606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [969]	training's rmse: 0.775581	valid_1's rmse: 0.902573
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [970]	training's rmse: 0.775563	valid_1's rmse: 0.902572
# [971]	training's rmse: 0.775516	valid_1's rmse: 0.902573
# [972]	training's rmse: 0.775469	valid_1's rmse: 0.902583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [973]	training's rmse: 0.775439	valid_1's rmse: 0.902582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [974]	training's rmse: 0.775411	valid_1's rmse: 0.902581
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [975]	training's rmse: 0.775387	valid_1's rmse: 0.902574
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [976]	training's rmse: 0.775339	valid_1's rmse: 0.902636
# [977]	training's rmse: 0.775266	valid_1's rmse: 0.902659
# [978]	training's rmse: 0.775198	valid_1's rmse: 0.902681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [979]	training's rmse: 0.775158	valid_1's rmse: 0.902707
# [980]	training's rmse: 0.775123	valid_1's rmse: 0.902715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [981]	training's rmse: 0.775099	valid_1's rmse: 0.902722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [982]	training's rmse: 0.77507	valid_1's rmse: 0.902717
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [983]	training's rmse: 0.775045	valid_1's rmse: 0.902724
# [984]	training's rmse: 0.775008	valid_1's rmse: 0.902747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [985]	training's rmse: 0.774983	valid_1's rmse: 0.90274
# [986]	training's rmse: 0.774944	valid_1's rmse: 0.902733
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [987]	training's rmse: 0.774914	valid_1's rmse: 0.902723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [988]	training's rmse: 0.774889	valid_1's rmse: 0.902715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [989]	training's rmse: 0.774855	valid_1's rmse: 0.902734
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [990]	training's rmse: 0.774822	valid_1's rmse: 0.902735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [991]	training's rmse: 0.774784	valid_1's rmse: 0.902756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [992]	training's rmse: 0.77476	valid_1's rmse: 0.902755
# [993]	training's rmse: 0.774686	valid_1's rmse: 0.90275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [994]	training's rmse: 0.774665	valid_1's rmse: 0.902752
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [995]	training's rmse: 0.774646	valid_1's rmse: 0.902746
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [996]	training's rmse: 0.7746	valid_1's rmse: 0.902749
# [997]	training's rmse: 0.774533	valid_1's rmse: 0.902715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [998]	training's rmse: 0.774513	valid_1's rmse: 0.90271
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [999]	training's rmse: 0.774491	valid_1's rmse: 0.902706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's rmse: 0.774464	valid_1's rmse: 0.902701

# %% [markdown]
# # 训练33个月

# %%
"""建模"""
trainData = matrix[matrix['date_block_num'] < 34]
label_train = trainData['item_cnt_month']
X_train = trainData.drop('item_cnt_month', axis=1)

train_data = lgb.Dataset(data=X_train, label=label_train)
params = {
    'objective': 'regression',  # 回归
    'metric': 'rmse',   # 回归问题选择rmse
    'n_estimators': 920,
    'max_depth': 8,
    'num_leaves': 200,   # 每个弱学习器拥有的叶子的数量
    'learning_rate': 0.01,
    'bagging_fraction': 0.9,    # 每次训练“弱学习器”用的数据比例（应该也是随机的），用于加快训练速度和减小过拟合
    'feature_fraction': 0.3,   # 每次迭代过程中，随机选择30%的特征建树（弱学习器）
    'bagging_seed': 0,
    'early_stop_rounds': 50
}
lgb_model = lgb.train(params, train_data, valid_sets=[train_data])
# Out:
# [LightGBM] [Warning] Unknown parameter: early_stop_rounds
# [LightGBM] [Warning] Unknown parameter: early_stop_rounds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.231536 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9550
# [LightGBM] [Info] Number of data points in the train set: 6425094, number of used features: 58
# [LightGBM] [Info] Start training from score 0.287729
# [1]	training's rmse: 1.18242
# [2]	training's rmse: 1.178
# [3]	training's rmse: 1.17375
# [4]	training's rmse: 1.16888
# [5]	training's rmse: 1.16521
# [6]	training's rmse: 1.16073
# [7]	training's rmse: 1.15741
# [8]	training's rmse: 1.15289
# [9]	training's rmse: 1.14903
# [10]	training's rmse: 1.14578
# [11]	training's rmse: 1.14268
# [12]	training's rmse: 1.13879
# [13]	training's rmse: 1.13415
# [14]	training's rmse: 1.12997
# [15]	training's rmse: 1.12586
# [16]	training's rmse: 1.12209
# [17]	training's rmse: 1.11835
# [18]	training's rmse: 1.11454
# [19]	training's rmse: 1.11147
# [20]	training's rmse: 1.10846
# [21]	training's rmse: 1.1051
# [22]	training's rmse: 1.10272
# [23]	training's rmse: 1.09997
# [24]	training's rmse: 1.09658
# [25]	training's rmse: 1.09305
# [26]	training's rmse: 1.09002
# [27]	training's rmse: 1.0863
# [28]	training's rmse: 1.08335
# [29]	training's rmse: 1.08001
# [30]	training's rmse: 1.07686
# [31]	training's rmse: 1.0737
# [32]	training's rmse: 1.0705
# [33]	training's rmse: 1.06738
# [34]	training's rmse: 1.0642
# [35]	training's rmse: 1.06103
# [36]	training's rmse: 1.05832
# [37]	training's rmse: 1.0549
# [38]	training's rmse: 1.05227
# [39]	training's rmse: 1.04928
# [40]	training's rmse: 1.0461
# [41]	training's rmse: 1.04324
# [42]	training's rmse: 1.04121
# [43]	training's rmse: 1.03861
# [44]	training's rmse: 1.0359
# [45]	training's rmse: 1.0332
# [46]	training's rmse: 1.03063
# [47]	training's rmse: 1.02775
# [48]	training's rmse: 1.02588
# [49]	training's rmse: 1.02315
# [50]	training's rmse: 1.021
# [51]	training's rmse: 1.01857
# [52]	training's rmse: 1.01588
# [53]	training's rmse: 1.01369
# [54]	training's rmse: 1.01194
# [55]	training's rmse: 1.00984
# [56]	training's rmse: 1.0071
# [57]	training's rmse: 1.0049
# [58]	training's rmse: 1.00267
# [59]	training's rmse: 1.00095
# [60]	training's rmse: 0.998578
# [61]	training's rmse: 0.996183
# [62]	training's rmse: 0.994572
# [63]	training's rmse: 0.992525
# [64]	training's rmse: 0.990424
# [65]	training's rmse: 0.988474
# [66]	training's rmse: 0.986379
# [67]	training's rmse: 0.984047
# [68]	training's rmse: 0.98182
# [69]	training's rmse: 0.979753
# [70]	training's rmse: 0.978355
# [71]	training's rmse: 0.976865
# [72]	training's rmse: 0.974979
# [73]	training's rmse: 0.973058
# [74]	training's rmse: 0.971179
# [75]	training's rmse: 0.96953
# [76]	training's rmse: 0.968276
# [77]	training's rmse: 0.966964
# [78]	training's rmse: 0.965181
# [79]	training's rmse: 0.963814
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	training's rmse: 0.962905
# [81]	training's rmse: 0.961253
# [82]	training's rmse: 0.959702
# [83]	training's rmse: 0.958138
# [84]	training's rmse: 0.956571
# [85]	training's rmse: 0.955069
# [86]	training's rmse: 0.953165
# [87]	training's rmse: 0.951561
# [88]	training's rmse: 0.950044
# [89]	training's rmse: 0.948546
# [90]	training's rmse: 0.947198
# [91]	training's rmse: 0.946137
# [92]	training's rmse: 0.944738
# [93]	training's rmse: 0.943438
# [94]	training's rmse: 0.942086
# [95]	training's rmse: 0.940646
# [96]	training's rmse: 0.939118
# [97]	training's rmse: 0.938315
# [98]	training's rmse: 0.937071
# [99]	training's rmse: 0.935321
# [100]	training's rmse: 0.933844
# [101]	training's rmse: 0.932547
# [102]	training's rmse: 0.931301
# [103]	training's rmse: 0.930059
# [104]	training's rmse: 0.928817
# [105]	training's rmse: 0.927629
# [106]	training's rmse: 0.926452
# [107]	training's rmse: 0.925239
# [108]	training's rmse: 0.92402
# [109]	training's rmse: 0.923166
# [110]	training's rmse: 0.921959
# [111]	training's rmse: 0.920602
# [112]	training's rmse: 0.919712
# [113]	training's rmse: 0.918548
# [114]	training's rmse: 0.917453
# [115]	training's rmse: 0.916321
# [116]	training's rmse: 0.915218
# [117]	training's rmse: 0.91412
# [118]	training's rmse: 0.913073
# [119]	training's rmse: 0.912284
# [120]	training's rmse: 0.911312
# [121]	training's rmse: 0.910738
# [122]	training's rmse: 0.909675
# [123]	training's rmse: 0.908739
# [124]	training's rmse: 0.908211
# [125]	training's rmse: 0.907065
# [126]	training's rmse: 0.905929
# [127]	training's rmse: 0.90537
# [128]	training's rmse: 0.904368
# [129]	training's rmse: 0.903543
# [130]	training's rmse: 0.902705
# [131]	training's rmse: 0.901847
# [132]	training's rmse: 0.90115
# [133]	training's rmse: 0.900284
# [134]	training's rmse: 0.89946
# [135]	training's rmse: 0.898556
# [136]	training's rmse: 0.898033
# [137]	training's rmse: 0.897159
# [138]	training's rmse: 0.896654
# [139]	training's rmse: 0.895737
# [140]	training's rmse: 0.894976
# [141]	training's rmse: 0.894471
# [142]	training's rmse: 0.893819
# [143]	training's rmse: 0.893147
# [144]	training's rmse: 0.892365
# [145]	training's rmse: 0.891891
# [146]	training's rmse: 0.890972
# [147]	training's rmse: 0.890363
# [148]	training's rmse: 0.889594
# [149]	training's rmse: 0.888782
# [150]	training's rmse: 0.887817
# [151]	training's rmse: 0.887312
# [152]	training's rmse: 0.886624
# [153]	training's rmse: 0.886177
# [154]	training's rmse: 0.885367
# [155]	training's rmse: 0.884498
# [156]	training's rmse: 0.883724
# [157]	training's rmse: 0.883231
# [158]	training's rmse: 0.882533
# [159]	training's rmse: 0.881906
# [160]	training's rmse: 0.88113
# [161]	training's rmse: 0.880338
# [162]	training's rmse: 0.879574
# [163]	training's rmse: 0.879204
# [164]	training's rmse: 0.878582
# [165]	training's rmse: 0.877994
# [166]	training's rmse: 0.877504
# [167]	training's rmse: 0.876928
# [168]	training's rmse: 0.876239
# [169]	training's rmse: 0.875496
# [170]	training's rmse: 0.875012
# [171]	training's rmse: 0.874406
# [172]	training's rmse: 0.873679
# [173]	training's rmse: 0.873132
# [174]	training's rmse: 0.872546
# [175]	training's rmse: 0.872108
# [176]	training's rmse: 0.871573
# [177]	training's rmse: 0.870904
# [178]	training's rmse: 0.870503
# [179]	training's rmse: 0.86996
# [180]	training's rmse: 0.869321
# [181]	training's rmse: 0.868845
# [182]	training's rmse: 0.868424
# [183]	training's rmse: 0.867782
# [184]	training's rmse: 0.867376
# [185]	training's rmse: 0.866832
# [186]	training's rmse: 0.866425
# [187]	training's rmse: 0.866002
# [188]	training's rmse: 0.865649
# [189]	training's rmse: 0.865227
# [190]	training's rmse: 0.864812
# [191]	training's rmse: 0.864204
# [192]	training's rmse: 0.86383
# [193]	training's rmse: 0.863369
# [194]	training's rmse: 0.86296
# [195]	training's rmse: 0.862479
# [196]	training's rmse: 0.862278
# [197]	training's rmse: 0.861835
# [198]	training's rmse: 0.861416
# [199]	training's rmse: 0.861086
# [200]	training's rmse: 0.860466
# [201]	training's rmse: 0.860114
# [202]	training's rmse: 0.859639
# [203]	training's rmse: 0.859376
# [204]	training's rmse: 0.859012
# [205]	training's rmse: 0.85864
# [206]	training's rmse: 0.858342
# [207]	training's rmse: 0.857995
# [208]	training's rmse: 0.857483
# [209]	training's rmse: 0.857019
# [210]	training's rmse: 0.856496
# [211]	training's rmse: 0.85619
# [212]	training's rmse: 0.855813
# [213]	training's rmse: 0.855179
# [214]	training's rmse: 0.854807
# [215]	training's rmse: 0.854378
# [216]	training's rmse: 0.854028
# [217]	training's rmse: 0.853655
# [218]	training's rmse: 0.85315
# [219]	training's rmse: 0.852991
# [220]	training's rmse: 0.852643
# [221]	training's rmse: 0.852353
# [222]	training's rmse: 0.851832
# [223]	training's rmse: 0.851539
# [224]	training's rmse: 0.85115
# [225]	training's rmse: 0.850741
# [226]	training's rmse: 0.850472
# [227]	training's rmse: 0.850138
# [228]	training's rmse: 0.849905
# [229]	training's rmse: 0.849578
# [230]	training's rmse: 0.849363
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [231]	training's rmse: 0.849091
# [232]	training's rmse: 0.84881
# [233]	training's rmse: 0.84858
# [234]	training's rmse: 0.848343
# [235]	training's rmse: 0.847917
# [236]	training's rmse: 0.847653
# [237]	training's rmse: 0.847434
# [238]	training's rmse: 0.847291
# [239]	training's rmse: 0.846947
# [240]	training's rmse: 0.846707
# [241]	training's rmse: 0.846455
# [242]	training's rmse: 0.846224
# [243]	training's rmse: 0.845795
# [244]	training's rmse: 0.845451
# [245]	training's rmse: 0.845116
# [246]	training's rmse: 0.844896
# [247]	training's rmse: 0.844585
# [248]	training's rmse: 0.844216
# [249]	training's rmse: 0.843994
# [250]	training's rmse: 0.843728
# [251]	training's rmse: 0.84342
# [252]	training's rmse: 0.843188
# [253]	training's rmse: 0.842941
# [254]	training's rmse: 0.842765
# [255]	training's rmse: 0.842619
# [256]	training's rmse: 0.842367
# [257]	training's rmse: 0.842172
# [258]	training's rmse: 0.841992
# [259]	training's rmse: 0.841739
# [260]	training's rmse: 0.841517
# [261]	training's rmse: 0.841312
# [262]	training's rmse: 0.840974
# [263]	training's rmse: 0.840794
# [264]	training's rmse: 0.840608
# [265]	training's rmse: 0.840274
# [266]	training's rmse: 0.840041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	training's rmse: 0.839875
# [268]	training's rmse: 0.839619
# [269]	training's rmse: 0.839326
# [270]	training's rmse: 0.839115
# [271]	training's rmse: 0.838934
# [272]	training's rmse: 0.838788
# [273]	training's rmse: 0.838555
# [274]	training's rmse: 0.838276
# [275]	training's rmse: 0.838062
# [276]	training's rmse: 0.837881
# [277]	training's rmse: 0.837642
# [278]	training's rmse: 0.837453
# [279]	training's rmse: 0.83719
# [280]	training's rmse: 0.83681
# [281]	training's rmse: 0.836568
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	training's rmse: 0.836339
# [283]	training's rmse: 0.83611
# [284]	training's rmse: 0.836
# [285]	training's rmse: 0.835792
# [286]	training's rmse: 0.835627
# [287]	training's rmse: 0.835422
# [288]	training's rmse: 0.835202
# [289]	training's rmse: 0.835046
# [290]	training's rmse: 0.834893
# [291]	training's rmse: 0.834526
# [292]	training's rmse: 0.834397
# [293]	training's rmse: 0.834221
# [294]	training's rmse: 0.833908
# [295]	training's rmse: 0.833675
# [296]	training's rmse: 0.833554
# [297]	training's rmse: 0.833406
# [298]	training's rmse: 0.833261
# [299]	training's rmse: 0.833106
# [300]	training's rmse: 0.832898
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	training's rmse: 0.832727
# [302]	training's rmse: 0.832441
# [303]	training's rmse: 0.832349
# [304]	training's rmse: 0.832032
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	training's rmse: 0.831951
# [306]	training's rmse: 0.831857
# [307]	training's rmse: 0.831471
# [308]	training's rmse: 0.831224
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [309]	training's rmse: 0.831064
# [310]	training's rmse: 0.830917
# [311]	training's rmse: 0.830799
# [312]	training's rmse: 0.830601
# [313]	training's rmse: 0.830411
# [314]	training's rmse: 0.830202
# [315]	training's rmse: 0.829946
# [316]	training's rmse: 0.829816
# [317]	training's rmse: 0.829553
# [318]	training's rmse: 0.82932
# [319]	training's rmse: 0.82909
# [320]	training's rmse: 0.828909
# [321]	training's rmse: 0.828815
# [322]	training's rmse: 0.828558
# [323]	training's rmse: 0.828352
# [324]	training's rmse: 0.828237
# [325]	training's rmse: 0.828102
# [326]	training's rmse: 0.827994
# [327]	training's rmse: 0.827576
# [328]	training's rmse: 0.827429
# [329]	training's rmse: 0.827274
# [330]	training's rmse: 0.827122
# [331]	training's rmse: 0.826911
# [332]	training's rmse: 0.826788
# [333]	training's rmse: 0.826653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	training's rmse: 0.826492
# [335]	training's rmse: 0.826285
# [336]	training's rmse: 0.826054
# [337]	training's rmse: 0.825888
# [338]	training's rmse: 0.825743
# [339]	training's rmse: 0.825513
# [340]	training's rmse: 0.825348
# [341]	training's rmse: 0.825201
# [342]	training's rmse: 0.825047
# [343]	training's rmse: 0.824916
# [344]	training's rmse: 0.824847
# [345]	training's rmse: 0.824595
# [346]	training's rmse: 0.8245
# [347]	training's rmse: 0.824375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	training's rmse: 0.824185
# [349]	training's rmse: 0.824019
# [350]	training's rmse: 0.823813
# [351]	training's rmse: 0.823669
# [352]	training's rmse: 0.823559
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	training's rmse: 0.823415
# [354]	training's rmse: 0.823284
# [355]	training's rmse: 0.823144
# [356]	training's rmse: 0.823
# [357]	training's rmse: 0.822867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [358]	training's rmse: 0.822818
# [359]	training's rmse: 0.822686
# [360]	training's rmse: 0.822542
# [361]	training's rmse: 0.822468
# [362]	training's rmse: 0.822386
# [363]	training's rmse: 0.822247
# [364]	training's rmse: 0.822064
# [365]	training's rmse: 0.821944
# [366]	training's rmse: 0.821793
# [367]	training's rmse: 0.821585
# [368]	training's rmse: 0.821517
# [369]	training's rmse: 0.821399
# [370]	training's rmse: 0.821258
# [371]	training's rmse: 0.821158
# [372]	training's rmse: 0.820924
# [373]	training's rmse: 0.820857
# [374]	training's rmse: 0.820728
# [375]	training's rmse: 0.820588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	training's rmse: 0.820438
# [377]	training's rmse: 0.820357
# [378]	training's rmse: 0.8203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	training's rmse: 0.820206
# [380]	training's rmse: 0.820051
# [381]	training's rmse: 0.819939
# [382]	training's rmse: 0.819684
# [383]	training's rmse: 0.819548
# [384]	training's rmse: 0.819432
# [385]	training's rmse: 0.819266
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	training's rmse: 0.81917
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387]	training's rmse: 0.819112
# [388]	training's rmse: 0.818861
# [389]	training's rmse: 0.818737
# [390]	training's rmse: 0.818419
# [391]	training's rmse: 0.818306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	training's rmse: 0.818238
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	training's rmse: 0.81814
# [394]	training's rmse: 0.818053
# [395]	training's rmse: 0.817931
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	training's rmse: 0.817784
# [397]	training's rmse: 0.817547
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	training's rmse: 0.817409
# [399]	training's rmse: 0.81727
# [400]	training's rmse: 0.817178
# [401]	training's rmse: 0.81705
# [402]	training's rmse: 0.816929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [403]	training's rmse: 0.816823
# [404]	training's rmse: 0.816734
# [405]	training's rmse: 0.816641
# [406]	training's rmse: 0.816507
# [407]	training's rmse: 0.816446
# [408]	training's rmse: 0.816317
# [409]	training's rmse: 0.816227
# [410]	training's rmse: 0.816124
# [411]	training's rmse: 0.815953
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [412]	training's rmse: 0.815867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [413]	training's rmse: 0.815747
# [414]	training's rmse: 0.815603
# [415]	training's rmse: 0.815469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [416]	training's rmse: 0.815391
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [417]	training's rmse: 0.815279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [418]	training's rmse: 0.815218
# [419]	training's rmse: 0.815076
# [420]	training's rmse: 0.814948
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [421]	training's rmse: 0.814894
# [422]	training's rmse: 0.814833
# [423]	training's rmse: 0.814694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [424]	training's rmse: 0.814607
# [425]	training's rmse: 0.81431
# [426]	training's rmse: 0.814135
# [427]	training's rmse: 0.814028
# [428]	training's rmse: 0.81382
# [429]	training's rmse: 0.813652
# [430]	training's rmse: 0.813496
# [431]	training's rmse: 0.813357
# [432]	training's rmse: 0.813279
# [433]	training's rmse: 0.813184
# [434]	training's rmse: 0.813082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [435]	training's rmse: 0.81301
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [436]	training's rmse: 0.812951
# [437]	training's rmse: 0.812892
# [438]	training's rmse: 0.812799
# [439]	training's rmse: 0.812727
# [440]	training's rmse: 0.812625
# [441]	training's rmse: 0.812558
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [442]	training's rmse: 0.812486
# [443]	training's rmse: 0.812281
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [444]	training's rmse: 0.812203
# [445]	training's rmse: 0.812096
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [446]	training's rmse: 0.811977
# [447]	training's rmse: 0.811803
# [448]	training's rmse: 0.811734
# [449]	training's rmse: 0.811618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	training's rmse: 0.81155
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [451]	training's rmse: 0.811447
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [452]	training's rmse: 0.811364
# [453]	training's rmse: 0.811285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [454]	training's rmse: 0.811184
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [455]	training's rmse: 0.811062
# [456]	training's rmse: 0.810971
# [457]	training's rmse: 0.810782
# [458]	training's rmse: 0.810662
# [459]	training's rmse: 0.810564
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [460]	training's rmse: 0.81048
# [461]	training's rmse: 0.810425
# [462]	training's rmse: 0.810309
# [463]	training's rmse: 0.810228
# [464]	training's rmse: 0.810146
# [465]	training's rmse: 0.810062
# [466]	training's rmse: 0.809923
# [467]	training's rmse: 0.809864
# [468]	training's rmse: 0.809789
# [469]	training's rmse: 0.809709
# [470]	training's rmse: 0.809602
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [471]	training's rmse: 0.809531
# [472]	training's rmse: 0.809392
# [473]	training's rmse: 0.809317
# [474]	training's rmse: 0.809268
# [475]	training's rmse: 0.809214
# [476]	training's rmse: 0.809119
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [477]	training's rmse: 0.809045
# [478]	training's rmse: 0.809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [479]	training's rmse: 0.808929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [480]	training's rmse: 0.808879
# [481]	training's rmse: 0.808742
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [482]	training's rmse: 0.80868
# [483]	training's rmse: 0.808544
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [484]	training's rmse: 0.808458
# [485]	training's rmse: 0.808261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [486]	training's rmse: 0.808195
# [487]	training's rmse: 0.808132
# [488]	training's rmse: 0.807958
# [489]	training's rmse: 0.807834
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [490]	training's rmse: 0.807787
# [491]	training's rmse: 0.807685
# [492]	training's rmse: 0.807396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [493]	training's rmse: 0.807342
# [494]	training's rmse: 0.807241
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [495]	training's rmse: 0.807182
# [496]	training's rmse: 0.807124
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [497]	training's rmse: 0.807066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [498]	training's rmse: 0.807019
# [499]	training's rmse: 0.806963
# [500]	training's rmse: 0.806906
# [501]	training's rmse: 0.806728
# [502]	training's rmse: 0.806636
# [503]	training's rmse: 0.806565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [504]	training's rmse: 0.806502
# [505]	training's rmse: 0.806428
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [506]	training's rmse: 0.806376
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [507]	training's rmse: 0.806298
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [508]	training's rmse: 0.806179
# [509]	training's rmse: 0.8061
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [510]	training's rmse: 0.805987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [511]	training's rmse: 0.805936
# [512]	training's rmse: 0.80581
# [513]	training's rmse: 0.805708
# [514]	training's rmse: 0.805624
# [515]	training's rmse: 0.805509
# [516]	training's rmse: 0.805399
# [517]	training's rmse: 0.805333
# [518]	training's rmse: 0.805226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [519]	training's rmse: 0.805193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [520]	training's rmse: 0.805151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [521]	training's rmse: 0.805094
# [522]	training's rmse: 0.804975
# [523]	training's rmse: 0.804917
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [524]	training's rmse: 0.804872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [525]	training's rmse: 0.804784
# [526]	training's rmse: 0.804631
# [527]	training's rmse: 0.804506
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [528]	training's rmse: 0.804442
# [529]	training's rmse: 0.80436
# [530]	training's rmse: 0.804254
# [531]	training's rmse: 0.804177
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [532]	training's rmse: 0.804102
# [533]	training's rmse: 0.803994
# [534]	training's rmse: 0.803934
# [535]	training's rmse: 0.803813
# [536]	training's rmse: 0.803681
# [537]	training's rmse: 0.803606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [538]	training's rmse: 0.803551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [539]	training's rmse: 0.803483
# [540]	training's rmse: 0.80338
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [541]	training's rmse: 0.803318
# [542]	training's rmse: 0.803199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [543]	training's rmse: 0.803122
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [544]	training's rmse: 0.80305
# [545]	training's rmse: 0.802983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [546]	training's rmse: 0.802928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [547]	training's rmse: 0.802854
# [548]	training's rmse: 0.802796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [549]	training's rmse: 0.802738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	training's rmse: 0.802672
# [551]	training's rmse: 0.802624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [552]	training's rmse: 0.802584
# [553]	training's rmse: 0.802483
# [554]	training's rmse: 0.802356
# [555]	training's rmse: 0.802172
# [556]	training's rmse: 0.802091
# [557]	training's rmse: 0.802017
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [558]	training's rmse: 0.801962
# [559]	training's rmse: 0.801908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [560]	training's rmse: 0.801861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [561]	training's rmse: 0.801788
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [562]	training's rmse: 0.801759
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [563]	training's rmse: 0.801719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [564]	training's rmse: 0.80169
# [565]	training's rmse: 0.80163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [566]	training's rmse: 0.801595
# [567]	training's rmse: 0.80152
# [568]	training's rmse: 0.801473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [569]	training's rmse: 0.801438
# [570]	training's rmse: 0.801363
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [571]	training's rmse: 0.80126
# [572]	training's rmse: 0.801174
# [573]	training's rmse: 0.801102
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [574]	training's rmse: 0.801064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [575]	training's rmse: 0.800977
# [576]	training's rmse: 0.800929
# [577]	training's rmse: 0.800569
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [578]	training's rmse: 0.800516
# [579]	training's rmse: 0.8004
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [580]	training's rmse: 0.800353
# [581]	training's rmse: 0.800289
# [582]	training's rmse: 0.800193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [583]	training's rmse: 0.800137
# [584]	training's rmse: 0.800086
# [585]	training's rmse: 0.799976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [586]	training's rmse: 0.799919
# [587]	training's rmse: 0.799865
# [588]	training's rmse: 0.799736
# [589]	training's rmse: 0.799665
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [590]	training's rmse: 0.799639
# [591]	training's rmse: 0.799585
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [592]	training's rmse: 0.799513
# [593]	training's rmse: 0.799443
# [594]	training's rmse: 0.799207
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [595]	training's rmse: 0.799138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [596]	training's rmse: 0.799076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [597]	training's rmse: 0.799008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [598]	training's rmse: 0.798973
# [599]	training's rmse: 0.79882
# [600]	training's rmse: 0.798734
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [601]	training's rmse: 0.798689
# [602]	training's rmse: 0.798605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [603]	training's rmse: 0.798558
# [604]	training's rmse: 0.798495
# [605]	training's rmse: 0.798436
# [606]	training's rmse: 0.798314
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [607]	training's rmse: 0.798263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [608]	training's rmse: 0.798183
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [609]	training's rmse: 0.798135
# [610]	training's rmse: 0.798083
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [611]	training's rmse: 0.798037
# [612]	training's rmse: 0.797999
# [613]	training's rmse: 0.797941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [614]	training's rmse: 0.797891
# [615]	training's rmse: 0.797656
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [616]	training's rmse: 0.797625
# [617]	training's rmse: 0.797462
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [618]	training's rmse: 0.79742
# [619]	training's rmse: 0.797348
# [620]	training's rmse: 0.797287
# [621]	training's rmse: 0.797206
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [622]	training's rmse: 0.79717
# [623]	training's rmse: 0.797058
# [624]	training's rmse: 0.797014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [625]	training's rmse: 0.796934
# [626]	training's rmse: 0.796876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [627]	training's rmse: 0.796828
# [628]	training's rmse: 0.796772
# [629]	training's rmse: 0.796711
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [630]	training's rmse: 0.796626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [631]	training's rmse: 0.79658
# [632]	training's rmse: 0.796478
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [633]	training's rmse: 0.796414
# [634]	training's rmse: 0.796317
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [635]	training's rmse: 0.796258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [636]	training's rmse: 0.79622
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [637]	training's rmse: 0.796192
# [638]	training's rmse: 0.796157
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [639]	training's rmse: 0.796111
# [640]	training's rmse: 0.796061
# [641]	training's rmse: 0.795954
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [642]	training's rmse: 0.795903
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [643]	training's rmse: 0.795783
# [644]	training's rmse: 0.795719
# [645]	training's rmse: 0.795661
# [646]	training's rmse: 0.795607
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [647]	training's rmse: 0.795571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [648]	training's rmse: 0.795525
# [649]	training's rmse: 0.795471
# [650]	training's rmse: 0.795431
# [651]	training's rmse: 0.795372
# [652]	training's rmse: 0.795338
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [653]	training's rmse: 0.795268
# [654]	training's rmse: 0.795227
# [655]	training's rmse: 0.795144
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [656]	training's rmse: 0.795114
# [657]	training's rmse: 0.795072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [658]	training's rmse: 0.795011
# [659]	training's rmse: 0.794928
# [660]	training's rmse: 0.794823
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [661]	training's rmse: 0.794788
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [662]	training's rmse: 0.794737
# [663]	training's rmse: 0.794633
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [664]	training's rmse: 0.794594
# [665]	training's rmse: 0.794511
# [666]	training's rmse: 0.794461
# [667]	training's rmse: 0.794368
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [668]	training's rmse: 0.794328
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [669]	training's rmse: 0.7943
# [670]	training's rmse: 0.794243
# [671]	training's rmse: 0.794164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [672]	training's rmse: 0.794122
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [673]	training's rmse: 0.794084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [674]	training's rmse: 0.794051
# [675]	training's rmse: 0.794
# [676]	training's rmse: 0.793959
# [677]	training's rmse: 0.793902
# [678]	training's rmse: 0.793847
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [679]	training's rmse: 0.793804
# [680]	training's rmse: 0.793739
# [681]	training's rmse: 0.793632
# [682]	training's rmse: 0.793572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [683]	training's rmse: 0.793502
# [684]	training's rmse: 0.793446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [685]	training's rmse: 0.793411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [686]	training's rmse: 0.793369
# [687]	training's rmse: 0.793327
# [688]	training's rmse: 0.793283
# [689]	training's rmse: 0.79324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [690]	training's rmse: 0.79321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [691]	training's rmse: 0.793174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [692]	training's rmse: 0.793107
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [693]	training's rmse: 0.793046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [694]	training's rmse: 0.793009
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [695]	training's rmse: 0.792974
# [696]	training's rmse: 0.792925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [697]	training's rmse: 0.792863
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [698]	training's rmse: 0.792842
# [699]	training's rmse: 0.79278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [700]	training's rmse: 0.792757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [701]	training's rmse: 0.792719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [702]	training's rmse: 0.792679
# [703]	training's rmse: 0.792632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [704]	training's rmse: 0.79258
# [705]	training's rmse: 0.792438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [706]	training's rmse: 0.792413
# [707]	training's rmse: 0.792325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [708]	training's rmse: 0.792289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [709]	training's rmse: 0.792234
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [710]	training's rmse: 0.792193
# [711]	training's rmse: 0.792116
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [712]	training's rmse: 0.792056
# [713]	training's rmse: 0.791975
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [714]	training's rmse: 0.791933
# [715]	training's rmse: 0.791865
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [716]	training's rmse: 0.791818
# [717]	training's rmse: 0.791745
# [718]	training's rmse: 0.79162
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [719]	training's rmse: 0.791569
# [720]	training's rmse: 0.791515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [721]	training's rmse: 0.791486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [722]	training's rmse: 0.791439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [723]	training's rmse: 0.791404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [724]	training's rmse: 0.791316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [725]	training's rmse: 0.791288
# [726]	training's rmse: 0.791225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [727]	training's rmse: 0.791188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [728]	training's rmse: 0.791134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [729]	training's rmse: 0.791109
# [730]	training's rmse: 0.791023
# [731]	training's rmse: 0.790948
# [732]	training's rmse: 0.790916
# [733]	training's rmse: 0.79089
# [734]	training's rmse: 0.790832
# [735]	training's rmse: 0.790766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [736]	training's rmse: 0.790659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [737]	training's rmse: 0.790612
# [738]	training's rmse: 0.790548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [739]	training's rmse: 0.790509
# [740]	training's rmse: 0.79047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [741]	training's rmse: 0.790444
# [742]	training's rmse: 0.790355
# [743]	training's rmse: 0.790289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [744]	training's rmse: 0.790257
# [745]	training's rmse: 0.790213
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [746]	training's rmse: 0.790167
# [747]	training's rmse: 0.790125
# [748]	training's rmse: 0.790094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [749]	training's rmse: 0.790054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's rmse: 0.790028
# [751]	training's rmse: 0.789942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [752]	training's rmse: 0.789897
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [753]	training's rmse: 0.789862
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [754]	training's rmse: 0.789824
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [755]	training's rmse: 0.789776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [756]	training's rmse: 0.789735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [757]	training's rmse: 0.789697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [758]	training's rmse: 0.789658
# [759]	training's rmse: 0.789587
# [760]	training's rmse: 0.789549
# [761]	training's rmse: 0.789469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [762]	training's rmse: 0.789437
# [763]	training's rmse: 0.78938
# [764]	training's rmse: 0.78934
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [765]	training's rmse: 0.78916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [766]	training's rmse: 0.789112
# [767]	training's rmse: 0.789069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [768]	training's rmse: 0.789035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [769]	training's rmse: 0.788996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [770]	training's rmse: 0.788963
# [771]	training's rmse: 0.788807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [772]	training's rmse: 0.788773
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [773]	training's rmse: 0.788736
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [774]	training's rmse: 0.788704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [775]	training's rmse: 0.788673
# [776]	training's rmse: 0.78861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [777]	training's rmse: 0.788581
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [778]	training's rmse: 0.788548
# [779]	training's rmse: 0.788455
# [780]	training's rmse: 0.788412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [781]	training's rmse: 0.788357
# [782]	training's rmse: 0.788292
# [783]	training's rmse: 0.788229
# [784]	training's rmse: 0.788085
# [785]	training's rmse: 0.788034
# [786]	training's rmse: 0.787985
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [787]	training's rmse: 0.787958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [788]	training's rmse: 0.787941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [789]	training's rmse: 0.787912
# [790]	training's rmse: 0.787851
# [791]	training's rmse: 0.787744
# [792]	training's rmse: 0.787677
# [793]	training's rmse: 0.787559
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [794]	training's rmse: 0.787519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [795]	training's rmse: 0.78749
# [796]	training's rmse: 0.787448
# [797]	training's rmse: 0.787404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [798]	training's rmse: 0.787379
# [799]	training's rmse: 0.787278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's rmse: 0.787252
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [801]	training's rmse: 0.787186
# [802]	training's rmse: 0.787148
# [803]	training's rmse: 0.787072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [804]	training's rmse: 0.787038
# [805]	training's rmse: 0.786998
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [806]	training's rmse: 0.786971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [807]	training's rmse: 0.786936
# [808]	training's rmse: 0.786684
# [809]	training's rmse: 0.786644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [810]	training's rmse: 0.786604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [811]	training's rmse: 0.786574
# [812]	training's rmse: 0.786524
# [813]	training's rmse: 0.786481
# [814]	training's rmse: 0.786385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [815]	training's rmse: 0.786348
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [816]	training's rmse: 0.786323
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [817]	training's rmse: 0.786273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [818]	training's rmse: 0.786252
# [819]	training's rmse: 0.786082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [820]	training's rmse: 0.786038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [821]	training's rmse: 0.786003
# [822]	training's rmse: 0.785914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [823]	training's rmse: 0.785876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [824]	training's rmse: 0.785826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [825]	training's rmse: 0.785787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [826]	training's rmse: 0.785764
# [827]	training's rmse: 0.78572
# [828]	training's rmse: 0.785617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [829]	training's rmse: 0.785573
# [830]	training's rmse: 0.785538
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [831]	training's rmse: 0.785516
# [832]	training's rmse: 0.785465
# [833]	training's rmse: 0.785434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [834]	training's rmse: 0.785382
# [835]	training's rmse: 0.785345
# [836]	training's rmse: 0.785276
# [837]	training's rmse: 0.785221
# [838]	training's rmse: 0.785187
# [839]	training's rmse: 0.785131
# [840]	training's rmse: 0.785077
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [841]	training's rmse: 0.785038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [842]	training's rmse: 0.784929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [843]	training's rmse: 0.784909
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [844]	training's rmse: 0.78487
# [845]	training's rmse: 0.784818
# [846]	training's rmse: 0.784774
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [847]	training's rmse: 0.784751
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [848]	training's rmse: 0.784709
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [849]	training's rmse: 0.784684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's rmse: 0.78464
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [851]	training's rmse: 0.784615
# [852]	training's rmse: 0.78452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [853]	training's rmse: 0.784498
# [854]	training's rmse: 0.784446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [855]	training's rmse: 0.784411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [856]	training's rmse: 0.784387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [857]	training's rmse: 0.784362
# [858]	training's rmse: 0.784293
# [859]	training's rmse: 0.784249
# [860]	training's rmse: 0.784198
# [861]	training's rmse: 0.784168
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [862]	training's rmse: 0.784103
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [863]	training's rmse: 0.784055
# [864]	training's rmse: 0.784028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [865]	training's rmse: 0.783996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [866]	training's rmse: 0.783976
# [867]	training's rmse: 0.783946
# [868]	training's rmse: 0.783903
# [869]	training's rmse: 0.783876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [870]	training's rmse: 0.783847
# [871]	training's rmse: 0.783809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [872]	training's rmse: 0.783741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [873]	training's rmse: 0.783715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [874]	training's rmse: 0.783691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [875]	training's rmse: 0.783569
# [876]	training's rmse: 0.783498
# [877]	training's rmse: 0.783453
# [878]	training's rmse: 0.783387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [879]	training's rmse: 0.783357
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [880]	training's rmse: 0.783327
# [881]	training's rmse: 0.783285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [882]	training's rmse: 0.783254
# [883]	training's rmse: 0.783196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [884]	training's rmse: 0.783175
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [885]	training's rmse: 0.783139
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [886]	training's rmse: 0.783111
# [887]	training's rmse: 0.783085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [888]	training's rmse: 0.783057
# [889]	training's rmse: 0.783004
# [890]	training's rmse: 0.782972
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [891]	training's rmse: 0.782859
# [892]	training's rmse: 0.782815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [893]	training's rmse: 0.78279
# [894]	training's rmse: 0.782737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [895]	training's rmse: 0.782702
# [896]	training's rmse: 0.782659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [897]	training's rmse: 0.782628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [898]	training's rmse: 0.782596
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [899]	training's rmse: 0.782577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	training's rmse: 0.78255
# [901]	training's rmse: 0.782512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [902]	training's rmse: 0.782455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [903]	training's rmse: 0.78243
# [904]	training's rmse: 0.782374
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [905]	training's rmse: 0.782353
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [906]	training's rmse: 0.782311
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [907]	training's rmse: 0.782273
# [908]	training's rmse: 0.782229
# [909]	training's rmse: 0.782181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [910]	training's rmse: 0.782151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [911]	training's rmse: 0.782127
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [912]	training's rmse: 0.782093
# [913]	training's rmse: 0.782018
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [914]	training's rmse: 0.781998
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [915]	training's rmse: 0.781962
# [916]	training's rmse: 0.781913
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [917]	training's rmse: 0.781878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [918]	training's rmse: 0.781846
# [919]	training's rmse: 0.781801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [920]	training's rmse: 0.781765

# %%
# test数据
testData = matrix[matrix['date_block_num'] == 34]
X_test = testData.drop('item_cnt_month', axis=1)

# 预测&生成文件
y_test = lgb_model.predict(X_test).clip(0, 20)
submission = pd.DataFrame({ 'ID': range(0, 214200), 'item_cnt_month': y_test})

test0 = test[test.item_id.isin(six_zero_item_id)]
ids = list(test0.ID.values)
submission.loc[submission.ID.isin(ids), 'item_cnt_month'] = 0.0
submission.to_csv('./submit/sub1.csv', index=False)
